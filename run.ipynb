# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
ls
# Out:
# conll_reader.py  evaluate.py               __pycache__/
# data/            extract_training_data.py  run.ipynb
# decoder.py       get_vocab.py              train_model.py

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
cd /content/gdrive/My\ Drive/
# Out:
# /content/gdrive/My Drive

# %%
cd 'Colab Notebooks'
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %%
cd hw3
# Out:
# /content/gdrive/My Drive/Colab Notebooks/hw3

# %%
# !python3 get_vocab.py data/train.conll data/words.vocab data/pos.vocab
# Out:
# Writing word indices...
# Writing POS indices...

# %%
# !python3 extract_training_data.py data/train.conll data/input_train.npy data/target_train.npy
# Out:
# Starting feature extraction... (each . represents 100 sentences)
# ...............................................................................................................................................................................................................................................................................................................................................................................................................
# Writing output...

# %%
# !python3 extract_training_data.py data/dev.conll data/input_dev.npy data/target_dev.npy
# Out:
# Starting feature extraction... (each . represents 100 sentences)
# ...................................................
# Writing output...

# %%
# !python3 train_model.py data/input_train.npy data/target_train.npy data/model.h5
# Out:
# Compiling model.
# 2022-11-10 15:01:14.204727: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Done loading data.
# 2022-11-10 15:01:15.509423: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 691424916 exceeds 10% of free system memory.
# Epoch 1/5
# 18996/18996 [==============================] - 61s 3ms/step - loss: 0.4852
# Epoch 2/5
# 18996/18996 [==============================] - 58s 3ms/step - loss: 0.4103
# Epoch 3/5
# 18996/18996 [==============================] - 58s 3ms/step - loss: 0.3978
# Epoch 4/5
# 18996/18996 [==============================] - 57s 3ms/step - loss: 0.3874
# Epoch 5/5
# 18996/18996 [==============================] - 58s 3ms/step - loss: 0.3840

# %%
# !python3 decoder.py data/model.h5 data/dev.conll
# Out:
# Streaming output truncated to the last 5000 lines.
# 27	loans	_	_	NNS	_	24	pobj	_	_
# 28	-LRB-	_	_	-LRB-	_	30	punct	_	_
# 29	mainly	_	_	RB	_	30	advmod	_	_
# 30	residential	_	_	JJ	_	27	rcmod	_	_
# 31	-RRB-	_	_	-RRB-	_	30	punct	_	_
# 32	,	_	_	,	_	3	punct	_	_
# 33	and	_	_	CC	_	3	cc	_	_
# 34	a	_	_	DT	_	37	det	_	_
# 35	19	_	_	CD	_	36	number	_	_
# 36	%	_	_	NN	_	37	amod	_	_
# 37	rise	_	_	NN	_	3	ccomp	_	_
# 38	in	_	_	IN	_	37	prep	_	_
# 39	consumer	_	_	NN	_	40	nn	_	_
# 40	loans	_	_	NNS	_	38	pobj	_	_
# 41	.	_	_	.	_	3	punct	_	_
#
# 1	These	_	_	DT	_	3	det	_	_
# 2	high-yielding	_	_	JJ	_	3	amod	_	_
# 3	loans	_	_	NNS	_	6	nsubj	_	_
# 4	in	_	_	IN	_	3	prep	_	_
# 5	effect	_	_	NN	_	4	pobj	_	_
# 6	replaced	_	_	VBD	_	0	root	_	_
# 7	some	_	_	DT	_	9	det	_	_
# 8	low-yielding	_	_	JJ	_	9	amod	_	_
# 9	assets	_	_	NNS	_	6	dobj	_	_
# 10	such	_	_	JJ	_	11	mwe	_	_
# 11	as	_	_	IN	_	17	mark	_	_
# 12	inter-bank	_	_	JJ	_	13	amod	_	_
# 13	loans	_	_	NNS	_	17	nsubjpass	_	_
# 14	,	_	_	,	_	13	punct	_	_
# 15	which	_	_	WDT	_	17	mwe	_	_
# 16	were	_	_	VBD	_	17	auxpass	_	_
# 17	allowed	_	_	VBN	_	9	vmod	_	_
# 18	to	_	_	TO	_	19	aux	_	_
# 19	decrease	_	_	VB	_	17	xcomp	_	_
# 20	.	_	_	.	_	6	punct	_	_
#
# 1	As	_	_	IN	_	11	mark	_	_
# 2	a	_	_	DT	_	3	det	_	_
# 3	result	_	_	NN	_	1	pobj	_	_
# 4	,	_	_	,	_	11	punct	_	_
# 5	Security	_	_	NNP	_	6	nn	_	_
# 6	Pacific	_	_	NNP	_	10	nn	_	_
# 7	's	_	_	POS	_	6	possessive	_	_
# 8	net	_	_	JJ	_	10	amod	_	_
# 9	interest	_	_	NN	_	10	nn	_	_
# 10	margin	_	_	NN	_	11	nsubj	_	_
# 11	fell	_	_	VBD	_	0	root	_	_
# 12	only	_	_	RB	_	15	amod	_	_
# 13	13	_	_	CD	_	15	num	_	_
# 14	basis	_	_	NN	_	15	nn	_	_
# 15	points	_	_	NNS	_	11	dobj	_	_
# 16	,	_	_	,	_	15	punct	_	_
# 17	a	_	_	DT	_	20	det	_	_
# 18	more	_	_	RBR	_	19	advmod	_	_
# 19	mild	_	_	JJ	_	20	amod	_	_
# 20	decrease	_	_	NN	_	15	conj	_	_
# 21	than	_	_	IN	_	20	prep	_	_
# 22	some	_	_	DT	_	24	det	_	_
# 23	major	_	_	JJ	_	24	amod	_	_
# 24	banks	_	_	NNS	_	21	pobj	_	_
# 25	outside	_	_	IN	_	24	advmod	_	_
# 26	California	_	_	NNP	_	31	nn	_	_
# 27	,	_	_	,	_	26	punct	_	_
# 28	which	_	_	WDT	_	31	nsubj	_	_
# 29	have	_	_	VBP	_	31	aux	_	_
# 30	been	_	_	VBN	_	31	aux	_	_
# 31	reporting	_	_	VBG	_	25	pcomp	_	_
# 32	more	_	_	RBR	_	34	amod	_	_
# 33	sluggish	_	_	JJ	_	34	amod	_	_
# 34	earnings	_	_	NNS	_	31	dobj	_	_
# 35	.	_	_	.	_	11	punct	_	_
#
# 1	Security	_	_	NNP	_	3	nn	_	_
# 2	Pacific	_	_	NNP	_	3	nn	_	_
# 3	shares	_	_	NNS	_	4	nsubj	_	_
# 4	closed	_	_	VBD	_	0	root	_	_
# 5	at	_	_	IN	_	4	prep	_	_
# 6	$	_	_	$	_	5	pobj	_	_
# 7	44.625	_	_	CD	_	6	num	_	_
# 8	,	_	_	,	_	4	punct	_	_
# 9	down	_	_	RB	_	4	advmod	_	_
# 10	37.5	_	_	CD	_	11	num	_	_
# 11	cents	_	_	NNS	_	9	pobj	_	_
# 12	,	_	_	,	_	4	punct	_	_
# 13	in	_	_	IN	_	4	prep	_	_
# 14	Big	_	_	NNP	_	17	nn	_	_
# 15	Board	_	_	NNP	_	17	nn	_	_
# 16	composite	_	_	JJ	_	17	amod	_	_
# 17	trading	_	_	NN	_	13	pobj	_	_
# 18	.	_	_	.	_	4	punct	_	_
#
# 1	The	_	_	DT	_	2	det	_	_
# 2	earnings	_	_	NNS	_	3	nsubj	_	_
# 3	represent	_	_	VBP	_	0	root	_	_
# 4	a	_	_	DT	_	6	det	_	_
# 5	0.89	_	_	CD	_	6	number	_	_
# 6	%	_	_	NN	_	3	dobj	_	_
# 7	return	_	_	NN	_	18	nn	_	_
# 8	on	_	_	IN	_	7	prep	_	_
# 9	assets	_	_	NNS	_	8	pobj	_	_
# 10	for	_	_	IN	_	9	prep	_	_
# 11	Security	_	_	NNP	_	10	pobj	_	_
# 12	Pacific	_	_	NNP	_	11	appos	_	_
# 13	,	_	_	,	_	7	punct	_	_
# 14	and	_	_	CC	_	7	cc	_	_
# 15	an	_	_	DT	_	18	det	_	_
# 16	18.9	_	_	CD	_	17	number	_	_
# 17	%	_	_	NN	_	18	amod	_	_
# 18	return	_	_	NN	_	6	conj	_	_
# 19	on	_	_	IN	_	18	prep	_	_
# 20	equity	_	_	NN	_	19	pobj	_	_
# 21	.	_	_	.	_	3	punct	_	_
#
# 1	The	_	_	DT	_	3	det	_	_
# 2	loan	_	_	NN	_	3	nn	_	_
# 3	growth	_	_	NN	_	4	nsubj	_	_
# 4	offset	_	_	VBD	_	0	root	_	_
# 5	continuing	_	_	VBG	_	8	amod	_	_
# 6	real-estate	_	_	NN	_	8	amod	_	_
# 7	loan	_	_	NN	_	8	nn	_	_
# 8	losses	_	_	NNS	_	4	dobj	_	_
# 9	in	_	_	IN	_	8	prep	_	_
# 10	the	_	_	DT	_	13	det	_	_
# 11	depressed	_	_	VBN	_	13	amod	_	_
# 12	Arizona	_	_	NNP	_	13	nn	_	_
# 13	market	_	_	NN	_	9	pobj	_	_
# 14	.	_	_	.	_	4	punct	_	_
#
# 1	Security	_	_	NNP	_	2	nn	_	_
# 2	Pacific	_	_	NNP	_	3	nsubj	_	_
# 3	reported	_	_	VBD	_	0	root	_	_
# 4	a	_	_	DT	_	7	det	_	_
# 5	33	_	_	CD	_	6	number	_	_
# 6	%	_	_	NN	_	7	amod	_	_
# 7	increase	_	_	NN	_	3	dobj	_	_
# 8	in	_	_	IN	_	7	prep	_	_
# 9	net	_	_	JJ	_	11	amod	_	_
# 10	credit	_	_	NN	_	11	nn	_	_
# 11	losses	_	_	NNS	_	8	pobj	_	_
# 12	for	_	_	IN	_	11	prep	_	_
# 13	the	_	_	DT	_	14	det	_	_
# 14	quarter	_	_	NN	_	12	pobj	_	_
# 15	,	_	_	,	_	11	punct	_	_
# 16	to	_	_	TO	_	7	prep	_	_
# 17	$	_	_	$	_	16	pobj	_	_
# 18	109	_	_	CD	_	19	number	_	_
# 19	million	_	_	CD	_	17	num	_	_
# 20	from	_	_	IN	_	7	prep	_	_
# 21	$	_	_	$	_	20	pobj	_	_
# 22	81.9	_	_	CD	_	23	number	_	_
# 23	million	_	_	CD	_	21	num	_	_
# 24	in	_	_	IN	_	7	prep	_	_
# 25	the	_	_	DT	_	27	det	_	_
# 26	year-ago	_	_	JJ	_	27	amod	_	_
# 27	period	_	_	NN	_	24	pobj	_	_
# 28	.	_	_	.	_	3	punct	_	_
#
# 1	Nonperforming	_	_	VBG	_	2	amod	_	_
# 2	loans	_	_	NNS	_	3	nsubj	_	_
# 3	grew	_	_	VBD	_	0	root	_	_
# 4	slightly	_	_	RB	_	3	advmod	_	_
# 5	to	_	_	TO	_	3	prep	_	_
# 6	$	_	_	$	_	5	pobj	_	_
# 7	1.75	_	_	CD	_	8	number	_	_
# 8	billion	_	_	CD	_	6	num	_	_
# 9	at	_	_	IN	_	6	prep	_	_
# 10	Sept.	_	_	NNP	_	9	pobj	_	_
# 11	30	_	_	CD	_	10	num	_	_
# 12	,	_	_	,	_	6	punct	_	_
# 13	from	_	_	IN	_	3	prep	_	_
# 14	$	_	_	$	_	13	pobj	_	_
# 15	1.7	_	_	CD	_	16	number	_	_
# 16	billion	_	_	CD	_	14	num	_	_
# 17	a	_	_	DT	_	18	det	_	_
# 18	year	_	_	NN	_	19	npadvmod	_	_
# 19	ago	_	_	RB	_	13	num	_	_
# 20	.	_	_	.	_	3	punct	_	_
#
# 1	Security	_	_	NNP	_	2	nn	_	_
# 2	Pacific	_	_	NNP	_	5	nn	_	_
# 3	's	_	_	POS	_	2	possessive	_	_
# 4	loan-loss	_	_	JJ	_	5	amod	_	_
# 5	provision	_	_	NN	_	6	nsubj	_	_
# 6	was	_	_	VBD	_	0	root	_	_
# 7	down	_	_	RB	_	6	advmod	_	_
# 8	22	_	_	CD	_	9	num	_	_
# 9	%	_	_	NN	_	7	pobj	_	_
# 10	,	_	_	,	_	9	punct	_	_
# 11	or	_	_	CC	_	9	cc	_	_
# 12	$	_	_	$	_	18	nsubj	_	_
# 13	30.4	_	_	CD	_	14	num	_	_
# 14	million	_	_	CD	_	12	num	_	_
# 15	,	_	_	,	_	12	punct	_	_
# 16	because	_	_	IN	_	18	mark	_	_
# 17	it	_	_	PRP	_	18	nsubj	_	_
# 18	added	_	_	VBD	_	9	conj	_	_
# 19	to	_	_	TO	_	18	prep	_	_
# 20	its	_	_	PRP$	_	22	poss	_	_
# 21	foreign-debt	_	_	JJ	_	22	amod	_	_
# 22	reserve	_	_	NN	_	19	pobj	_	_
# 23	the	_	_	DT	_	24	det	_	_
# 24	year	_	_	NN	_	22	tmod	_	_
# 25	before	_	_	RB	_	24	num	_	_
# 26	.	_	_	.	_	6	punct	_	_
#
# 1	Non-interest	_	_	JJ	_	2	amod	_	_
# 2	income	_	_	NN	_	3	nsubj	_	_
# 3	fell	_	_	VBD	_	0	root	_	_
# 4	6	_	_	CD	_	5	num	_	_
# 5	%	_	_	NN	_	3	dobj	_	_
# 6	in	_	_	IN	_	3	prep	_	_
# 7	the	_	_	DT	_	8	det	_	_
# 8	quarter	_	_	NN	_	6	pobj	_	_
# 9	,	_	_	,	_	3	punct	_	_
# 10	mainly	_	_	RB	_	12	advmod	_	_
# 11	because	_	_	IN	_	12	mark	_	_
# 12	of	_	_	IN	_	3	prep	_	_
# 13	an	_	_	DT	_	15	det	_	_
# 14	unusual	_	_	JJ	_	15	amod	_	_
# 15	gain	_	_	NN	_	12	pobj	_	_
# 16	a	_	_	DT	_	17	det	_	_
# 17	year	_	_	NN	_	18	npadvmod	_	_
# 18	earlier	_	_	RBR	_	15	advmod	_	_
# 19	from	_	_	IN	_	15	prep	_	_
# 20	the	_	_	DT	_	21	det	_	_
# 21	sale	_	_	NN	_	19	pobj	_	_
# 22	of	_	_	IN	_	21	prep	_	_
# 23	Hong	_	_	NNP	_	26	nn	_	_
# 24	Kong	_	_	NNP	_	26	nn	_	_
# 25	banking	_	_	NN	_	26	nn	_	_
# 26	operations	_	_	NNS	_	22	pobj	_	_
# 27	.	_	_	.	_	3	punct	_	_
#
# 1	Non-interest	_	_	JJ	_	2	amod	_	_
# 2	expense	_	_	NN	_	3	nsubj	_	_
# 3	grew	_	_	VBD	_	0	root	_	_
# 4	only	_	_	RB	_	6	advmod	_	_
# 5	4	_	_	CD	_	6	num	_	_
# 6	%	_	_	NN	_	3	dobj	_	_
# 7	in	_	_	IN	_	6	prep	_	_
# 8	the	_	_	DT	_	9	det	_	_
# 9	period	_	_	NN	_	7	pobj	_	_
# 10	.	_	_	.	_	3	punct	_	_
#
# 1	For	_	_	IN	_	7	prep	_	_
# 2	the	_	_	DT	_	4	det	_	_
# 3	nine	_	_	CD	_	4	num	_	_
# 4	months	_	_	NNS	_	1	pobj	_	_
# 5	,	_	_	,	_	7	punct	_	_
# 6	net	_	_	JJ	_	7	nsubj	_	_
# 7	rose	_	_	VBD	_	0	root	_	_
# 8	17	_	_	CD	_	9	num	_	_
# 9	%	_	_	NN	_	7	dobj	_	_
# 10	to	_	_	TO	_	7	prep	_	_
# 11	$	_	_	$	_	10	pobj	_	_
# 12	548.9	_	_	CD	_	13	number	_	_
# 13	million	_	_	CD	_	11	num	_	_
# 14	,	_	_	,	_	11	punct	_	_
# 15	or	_	_	CC	_	11	cc	_	_
# 16	$	_	_	$	_	11	conj	_	_
# 17	4.67	_	_	CD	_	16	num	_	_
# 18	a	_	_	DT	_	19	det	_	_
# 19	share	_	_	NN	_	16	npadvmod	_	_
# 20	,	_	_	,	_	11	punct	_	_
# 21	from	_	_	IN	_	7	prep	_	_
# 22	$	_	_	$	_	21	pobj	_	_
# 23	469.4	_	_	CD	_	24	number	_	_
# 24	million	_	_	CD	_	22	num	_	_
# 25	,	_	_	,	_	22	punct	_	_
# 26	or	_	_	CC	_	22	cc	_	_
# 27	$	_	_	$	_	22	conj	_	_
# 28	4.13	_	_	CD	_	27	num	_	_
# 29	a	_	_	DT	_	30	det	_	_
# 30	share	_	_	NN	_	27	npadvmod	_	_
# 31	,	_	_	,	_	22	punct	_	_
# 32	a	_	_	DT	_	33	det	_	_
# 33	year	_	_	NN	_	34	npadvmod	_	_
# 34	earlier	_	_	RBR	_	22	advmod	_	_
# 35	.	_	_	.	_	7	punct	_	_
#
# 1	The	_	_	DT	_	4	det	_	_
# 2	sudden	_	_	JJ	_	4	amod	_	_
# 3	``	_	_	``	_	4	punct	_	_
# 4	flight	_	_	NN	_	9	nsubj	_	_
# 5	to	_	_	TO	_	4	prep	_	_
# 6	quality	_	_	NN	_	5	pobj	_	_
# 7	''	_	_	''	_	6	punct	_	_
# 8	that	_	_	WDT	_	9	nsubj	_	_
# 9	triggered	_	_	VBD	_	0	root	_	_
# 10	Friday	_	_	NNP	_	14	poss	_	_
# 11	's	_	_	POS	_	10	possessive	_	_
# 12	explosive	_	_	JJ	_	14	amod	_	_
# 13	bond-market	_	_	JJ	_	14	nn	_	_
# 14	rally	_	_	NN	_	9	dobj	_	_
# 15	was	_	_	VBD	_	16	cop	_	_
# 16	reversed	_	_	VBN	_	14	rcmod	_	_
# 17	yesterday	_	_	NN	_	16	tmod	_	_
# 18	in	_	_	IN	_	16	prep	_	_
# 19	a	_	_	DT	_	21	det	_	_
# 20	``	_	_	``	_	21	punct	_	_
# 21	flight	_	_	NN	_	18	pobj	_	_
# 22	from	_	_	IN	_	21	prep	_	_
# 23	quality	_	_	NN	_	22	pobj	_	_
# 24	''	_	_	''	_	25	punct	_	_
# 25	rout	_	_	NN	_	23	conj	_	_
# 26	.	_	_	.	_	9	punct	_	_
#
# 1	The	_	_	DT	_	2	det	_	_
# 2	setback	_	_	NN	_	0	root	_	_
# 3	,	_	_	,	_	2	punct	_	_
# 4	in	_	_	IN	_	2	prep	_	_
# 5	which	_	_	WDT	_	4	pobj	_	_
# 6	Treasury	_	_	NNP	_	8	nn	_	_
# 7	bond	_	_	NN	_	8	nn	_	_
# 8	prices	_	_	NNS	_	4	pobj	_	_
# 9	plummeted	_	_	VBD	_	8	rcmod	_	_
# 10	,	_	_	,	_	2	punct	_	_
# 11	reflected	_	_	VBD	_	2	rcmod	_	_
# 12	a	_	_	DT	_	13	det	_	_
# 13	rebound	_	_	NN	_	11	dobj	_	_
# 14	in	_	_	IN	_	13	prep	_	_
# 15	the	_	_	DT	_	17	det	_	_
# 16	stock	_	_	NN	_	17	nn	_	_
# 17	market	_	_	NN	_	14	pobj	_	_
# 18	and	_	_	CC	_	13	cc	_	_
# 19	profit-taking	_	_	NN	_	13	dobj	_	_
# 20	.	_	_	.	_	2	punct	_	_
#
# 1	``	_	_	``	_	7	punct	_	_
# 2	It	_	_	PRP	_	7	nsubj	_	_
# 3	was	_	_	VBD	_	7	cop	_	_
# 4	a	_	_	DT	_	7	det	_	_
# 5	pretty	_	_	RB	_	6	advmod	_	_
# 6	wild	_	_	JJ	_	7	amod	_	_
# 7	day	_	_	NN	_	0	root	_	_
# 8	.	_	_	.	_	7	punct	_	_
#
# 1	Our	_	_	PRP$	_	2	poss	_	_
# 2	markets	_	_	NNS	_	12	nsubj	_	_
# 3	were	_	_	VBD	_	5	auxpass	_	_
# 4	closely	_	_	RB	_	5	advmod	_	_
# 5	tied	_	_	VBN	_	2	rcmod	_	_
# 6	to	_	_	TO	_	5	prep	_	_
# 7	the	_	_	DT	_	9	det	_	_
# 8	stock	_	_	NN	_	9	nn	_	_
# 9	market	_	_	NN	_	6	pobj	_	_
# 10	,	_	_	,	_	12	punct	_	_
# 11	''	_	_	''	_	12	punct	_	_
# 12	said	_	_	VBD	_	0	root	_	_
# 13	Joel	_	_	NNP	_	14	nn	_	_
# 14	Kazis	_	_	NNP	_	12	nsubj	_	_
# 15	,	_	_	,	_	14	punct	_	_
# 16	manager	_	_	NN	_	14	appos	_	_
# 17	of	_	_	IN	_	16	prep	_	_
# 18	trading	_	_	NN	_	17	pobj	_	_
# 19	at	_	_	IN	_	18	prep	_	_
# 20	Smith	_	_	NNP	_	21	nn	_	_
# 21	Barney	_	_	NNP	_	24	nn	_	_
# 22	,	_	_	,	_	21	punct	_	_
# 23	Harris	_	_	NNP	_	24	nn	_	_
# 24	Upham	_	_	NNP	_	26	nn	_	_
# 25	&	_	_	CC	_	24	cc	_	_
# 26	Co	_	_	NNP	_	19	pobj	_	_
# 27	.	_	_	.	_	12	punct	_	_
#
# 1	``	_	_	``	_	21	punct	_	_
# 2	Friday	_	_	NNP	_	4	nn	_	_
# 3	's	_	_	POS	_	2	possessive	_	_
# 4	flight	_	_	NN	_	21	ccomp	_	_
# 5	to	_	_	TO	_	4	prep	_	_
# 6	quality	_	_	NN	_	5	pobj	_	_
# 7	was	_	_	VBD	_	10	auxpass	_	_
# 8	no	_	_	DT	_	9	neg	_	_
# 9	longer	_	_	RBR	_	10	expl	_	_
# 10	needed	_	_	VBN	_	4	rcmod	_	_
# 11	once	_	_	IN	_	15	mark	_	_
# 12	the	_	_	DT	_	14	det	_	_
# 13	stock	_	_	NN	_	14	nn	_	_
# 14	market	_	_	NN	_	15	nsubj	_	_
# 15	found	_	_	VBD	_	10	conj	_	_
# 16	its	_	_	PRP$	_	17	poss	_	_
# 17	legs	_	_	NNS	_	15	dobj	_	_
# 18	,	_	_	,	_	21	punct	_	_
# 19	''	_	_	''	_	21	punct	_	_
# 20	he	_	_	PRP	_	21	nsubj	_	_
# 21	said	_	_	VBD	_	0	root	_	_
# 22	.	_	_	.	_	21	punct	_	_
#
# 1	Some	_	_	DT	_	3	det	_	_
# 2	fixed-income	_	_	JJ	_	3	nn	_	_
# 3	investors	_	_	NNS	_	5	nsubj	_	_
# 4	had	_	_	VBD	_	5	aux	_	_
# 5	expected	_	_	VBN	_	0	root	_	_
# 6	a	_	_	DT	_	8	det	_	_
# 7	further	_	_	JJ	_	8	amod	_	_
# 8	drop	_	_	NN	_	5	xcomp	_	_
# 9	in	_	_	IN	_	8	prep	_	_
# 10	stock	_	_	NN	_	11	nn	_	_
# 11	prices	_	_	NNS	_	9	pobj	_	_
# 12	after	_	_	IN	_	8	prep	_	_
# 13	the	_	_	DT	_	16	det	_	_
# 14	nearly	_	_	RB	_	15	advmod	_	_
# 15	200-point	_	_	JJ	_	16	amod	_	_
# 16	drop	_	_	NN	_	12	pobj	_	_
# 17	in	_	_	IN	_	16	prep	_	_
# 18	the	_	_	DT	_	22	det	_	_
# 19	Dow	_	_	NNP	_	22	nn	_	_
# 20	Jones	_	_	NNP	_	22	nn	_	_
# 21	Industrial	_	_	NNP	_	22	nn	_	_
# 22	Average	_	_	NNP	_	17	pobj	_	_
# 23	on	_	_	IN	_	16	prep	_	_
# 24	Friday	_	_	NNP	_	23	pobj	_	_
# 25	.	_	_	.	_	5	punct	_	_
#
# 1	That	_	_	IN	_	2	nsubj	_	_
# 2	caused	_	_	VBN	_	0	root	_	_
# 3	investors	_	_	NNS	_	2	dobj	_	_
# 4	to	_	_	TO	_	5	aux	_	_
# 5	flee	_	_	VB	_	2	xcomp	_	_
# 6	stocks	_	_	NNS	_	5	dobj	_	_
# 7	and	_	_	CC	_	5	cc	_	_
# 8	buy	_	_	VB	_	5	xcomp	_	_
# 9	high-quality	_	_	JJ	_	11	amod	_	_
# 10	Treasury	_	_	NNP	_	11	nn	_	_
# 11	bonds	_	_	NNS	_	8	dobj	_	_
# 12	,	_	_	,	_	8	punct	_	_
# 13	which	_	_	WDT	_	15	nsubj	_	_
# 14	are	_	_	VBP	_	15	cop	_	_
# 15	safer	_	_	JJR	_	8	conj	_	_
# 16	than	_	_	IN	_	15	prep	_	_
# 17	other	_	_	JJ	_	18	amod	_	_
# 18	types	_	_	NNS	_	16	pobj	_	_
# 19	of	_	_	IN	_	18	prep	_	_
# 20	securities	_	_	NNS	_	19	pobj	_	_
# 21	.	_	_	.	_	2	punct	_	_
#
# 1	But	_	_	CC	_	4	cc	_	_
# 2	when	_	_	WRB	_	4	advmod	_	_
# 3	stocks	_	_	NNS	_	4	nsubj	_	_
# 4	began	_	_	VBD	_	0	root	_	_
# 5	to	_	_	TO	_	6	aux	_	_
# 6	climb	_	_	VB	_	4	xcomp	_	_
# 7	instead	_	_	RB	_	6	advmod	_	_
# 8	,	_	_	,	_	6	punct	_	_
# 9	prices	_	_	NNS	_	6	dobj	_	_
# 10	of	_	_	IN	_	9	prep	_	_
# 11	Treasury	_	_	NNP	_	12	nn	_	_
# 12	bonds	_	_	NNS	_	10	pobj	_	_
# 13	declined	_	_	VBD	_	6	conj	_	_
# 14	.	_	_	.	_	4	punct	_	_
#
# 1	Contributing	_	_	VBG	_	0	root	_	_
# 2	to	_	_	TO	_	1	prep	_	_
# 3	the	_	_	DT	_	5	det	_	_
# 4	selling	_	_	NN	_	5	nn	_	_
# 5	pressure	_	_	NN	_	2	pobj	_	_
# 6	were	_	_	VBD	_	7	cop	_	_
# 7	dispatches	_	_	NNS	_	1	conj	_	_
# 8	by	_	_	IN	_	7	prep	_	_
# 9	several	_	_	JJ	_	11	amod	_	_
# 10	investment	_	_	NN	_	11	nn	_	_
# 11	firms	_	_	NNS	_	8	pobj	_	_
# 12	advising	_	_	VBG	_	11	rcmod	_	_
# 13	clients	_	_	NNS	_	12	dobj	_	_
# 14	to	_	_	TO	_	15	aux	_	_
# 15	boost	_	_	VB	_	12	vmod	_	_
# 16	their	_	_	PRP$	_	18	nn	_	_
# 17	stock	_	_	NN	_	18	nn	_	_
# 18	holdings	_	_	NNS	_	15	dobj	_	_
# 19	and	_	_	CC	_	15	cc	_	_
# 20	reduce	_	_	VB	_	15	conj	_	_
# 21	the	_	_	DT	_	22	det	_	_
# 22	size	_	_	NN	_	20	dobj	_	_
# 23	of	_	_	IN	_	22	prep	_	_
# 24	their	_	_	PRP$	_	25	poss	_	_
# 25	cash	_	_	NN	_	23	pobj	_	_
# 26	or	_	_	CC	_	25	cc	_	_
# 27	bond	_	_	NN	_	28	nn	_	_
# 28	portfolios	_	_	NNS	_	25	conj	_	_
# 29	.	_	_	.	_	1	punct	_	_
#
# 1	Among	_	_	IN	_	0	root	_	_
# 2	the	_	_	DT	_	3	det	_	_
# 3	firms	_	_	NNS	_	1	pobj	_	_
# 4	were	_	_	VBD	_	1	pcomp	_	_
# 5	Merrill	_	_	NNP	_	6	nn	_	_
# 6	Lynch	_	_	NNP	_	8	nn	_	_
# 7	&	_	_	CC	_	6	cc	_	_
# 8	Co.	_	_	NNP	_	13	nn	_	_
# 9	and	_	_	CC	_	8	cc	_	_
# 10	Dean	_	_	NNP	_	13	nn	_	_
# 11	Witter	_	_	NNP	_	13	nn	_	_
# 12	Reynolds	_	_	NNP	_	13	nn	_	_
# 13	Inc	_	_	NNP	_	4	nsubj	_	_
# 14	.	_	_	.	_	1	punct	_	_
#
# 1	The	_	_	DT	_	3	det	_	_
# 2	bond	_	_	NN	_	3	nn	_	_
# 3	market	_	_	NN	_	4	nsubj	_	_
# 4	seemed	_	_	VBD	_	0	root	_	_
# 5	to	_	_	TO	_	6	aux	_	_
# 6	ignore	_	_	VB	_	4	xcomp	_	_
# 7	evidence	_	_	NN	_	6	dobj	_	_
# 8	that	_	_	IN	_	12	nsubj	_	_
# 9	the	_	_	DT	_	11	det	_	_
# 10	Federal	_	_	NNP	_	11	nn	_	_
# 11	Reserve	_	_	NNP	_	12	nsubj	_	_
# 12	eased	_	_	VBD	_	7	rcmod	_	_
# 13	credit	_	_	NN	_	14	nn	_	_
# 14	conditions	_	_	NNS	_	12	dobj	_	_
# 15	slightly	_	_	RB	_	12	advmod	_	_
# 16	by	_	_	IN	_	12	prep	_	_
# 17	allowing	_	_	VBG	_	16	pcomp	_	_
# 18	the	_	_	DT	_	21	det	_	_
# 19	federal	_	_	JJ	_	21	amod	_	_
# 20	funds	_	_	NNS	_	21	nn	_	_
# 21	rate	_	_	NN	_	17	dobj	_	_
# 22	to	_	_	TO	_	23	aux	_	_
# 23	drift	_	_	VB	_	17	xcomp	_	_
# 24	as	_	_	RB	_	25	advmod	_	_
# 25	low	_	_	JJ	_	23	advmod	_	_
# 26	as	_	_	IN	_	23	prep	_	_
# 27	8	_	_	CD	_	28	quantmod	_	_
# 28	1/2	_	_	CD	_	29	num	_	_
# 29	%	_	_	NN	_	26	pobj	_	_
# 30	.	_	_	.	_	4	punct	_	_
#
# 1	The	_	_	DT	_	4	det	_	_
# 2	closely	_	_	RB	_	3	advmod	_	_
# 3	watched	_	_	VBN	_	4	amod	_	_
# 4	rate	_	_	NN	_	15	nsubj	_	_
# 5	on	_	_	IN	_	4	prep	_	_
# 6	federal	_	_	JJ	_	7	amod	_	_
# 7	funds	_	_	NNS	_	5	pobj	_	_
# 8	,	_	_	,	_	4	punct	_	_
# 9	or	_	_	CC	_	4	cc	_	_
# 10	overnight	_	_	JJ	_	11	amod	_	_
# 11	loans	_	_	NNS	_	15	nsubj	_	_
# 12	between	_	_	IN	_	11	prep	_	_
# 13	banks	_	_	NNS	_	12	pobj	_	_
# 14	,	_	_	,	_	11	punct	_	_
# 15	slid	_	_	VBD	_	0	root	_	_
# 16	to	_	_	TO	_	15	prep	_	_
# 17	about	_	_	RB	_	16	pcomp	_	_
# 18	8	_	_	CD	_	19	number	_	_
# 19	3/4	_	_	CD	_	20	num	_	_
# 20	%	_	_	NN	_	17	num	_	_
# 21	last	_	_	JJ	_	22	amod	_	_
# 22	week	_	_	NN	_	20	npadvmod	_	_
# 23	,	_	_	,	_	15	punct	_	_
# 24	down	_	_	RB	_	15	advmod	_	_
# 25	from	_	_	IN	_	24	prep	_	_
# 26	its	_	_	PRP$	_	28	poss	_	_
# 27	perceived	_	_	VBN	_	28	amod	_	_
# 28	target	_	_	NN	_	25	pobj	_	_
# 29	level	_	_	NN	_	28	dobj	_	_
# 30	of	_	_	IN	_	29	prep	_	_
# 31	about	_	_	RB	_	30	num	_	_
# 32	9	_	_	CD	_	33	num	_	_
# 33	%	_	_	NN	_	31	pcomp	_	_
# 34	.	_	_	.	_	15	punct	_	_
#
# 1	The	_	_	DT	_	2	det	_	_
# 2	rate	_	_	NN	_	4	nsubjpass	_	_
# 3	is	_	_	VBZ	_	4	auxpass	_	_
# 4	considered	_	_	VBN	_	0	root	_	_
# 5	an	_	_	DT	_	7	det	_	_
# 6	early	_	_	JJ	_	7	amod	_	_
# 7	signal	_	_	NN	_	4	xcomp	_	_
# 8	of	_	_	IN	_	7	prep	_	_
# 9	changes	_	_	NNS	_	8	pobj	_	_
# 10	in	_	_	IN	_	9	prep	_	_
# 11	Fed	_	_	NNP	_	12	nn	_	_
# 12	policy	_	_	NN	_	10	pobj	_	_
# 13	.	_	_	.	_	4	punct	_	_
#
# 1	Traders	_	_	NNS	_	2	nsubj	_	_
# 2	said	_	_	VBD	_	0	root	_	_
# 3	yesterday	_	_	NN	_	6	tmod	_	_
# 4	's	_	_	POS	_	3	possessive	_	_
# 5	modest	_	_	JJ	_	6	amod	_	_
# 6	easing	_	_	NN	_	2	ccomp	_	_
# 7	did	_	_	VBD	_	9	aux	_	_
# 8	n't	_	_	RB	_	9	neg	_	_
# 9	stir	_	_	VB	_	6	dobj	_	_
# 10	much	_	_	JJ	_	11	amod	_	_
# 11	enthusiasm	_	_	NN	_	9	dobj	_	_
# 12	because	_	_	IN	_	17	mark	_	_
# 13	it	_	_	PRP	_	17	nsubjpass	_	_
# 14	had	_	_	VBD	_	17	aux	_	_
# 15	been	_	_	VBN	_	17	auxpass	_	_
# 16	widely	_	_	RB	_	17	advmod	_	_
# 17	expected	_	_	VBN	_	6	xcomp	_	_
# 18	.	_	_	.	_	2	punct	_	_
#
# 1	In	_	_	IN	_	6	prep	_	_
# 2	fact	_	_	NN	_	1	pobj	_	_
# 3	,	_	_	,	_	6	punct	_	_
# 4	some	_	_	DT	_	5	det	_	_
# 5	economists	_	_	NNS	_	6	nsubj	_	_
# 6	contend	_	_	VBP	_	0	root	_	_
# 7	that	_	_	IN	_	10	mark	_	_
# 8	the	_	_	DT	_	10	det	_	_
# 9	latest	_	_	JJS	_	10	amod	_	_
# 10	easing	_	_	NN	_	6	ccomp	_	_
# 11	started	_	_	VBD	_	10	conj	_	_
# 12	last	_	_	JJ	_	13	amod	_	_
# 13	week	_	_	NN	_	11	tmod	_	_
# 14	.	_	_	.	_	6	punct	_	_
#
# 1	Others	_	_	NNS	_	2	nsubj	_	_
# 2	note	_	_	VBP	_	0	root	_	_
# 3	that	_	_	IN	_	7	mark	_	_
# 4	some	_	_	DT	_	5	det	_	_
# 5	investors	_	_	NNS	_	7	nsubjpass	_	_
# 6	were	_	_	VBD	_	7	auxpass	_	_
# 7	disappointed	_	_	VBN	_	2	ccomp	_	_
# 8	because	_	_	IN	_	11	mark	_	_
# 9	they	_	_	PRP	_	11	nsubj	_	_
# 10	had	_	_	VBD	_	11	aux	_	_
# 11	expected	_	_	VBN	_	7	ccomp	_	_
# 12	a	_	_	DT	_	15	det	_	_
# 13	more	_	_	RBR	_	14	advmod	_	_
# 14	aggressive	_	_	JJ	_	15	amod	_	_
# 15	easing	_	_	NN	_	11	xcomp	_	_
# 16	.	_	_	.	_	2	punct	_	_
#
# 1	The	_	_	DT	_	2	det	_	_
# 2	Treasury	_	_	NNP	_	6	nn	_	_
# 3	's	_	_	POS	_	2	possessive	_	_
# 4	benchmark	_	_	NN	_	6	amod	_	_
# 5	30-year	_	_	JJ	_	6	amod	_	_
# 6	bond	_	_	NN	_	8	nsubj	_	_
# 7	,	_	_	,	_	6	punct	_	_
# 8	ended	_	_	VBD	_	0	root	_	_
# 9	about	_	_	RB	_	11	quantmod	_	_
# 10	1	_	_	CD	_	11	number	_	_
# 11	3/4	_	_	CD	_	12	num	_	_
# 12	points	_	_	NNS	_	8	dobj	_	_
# 13	lower	_	_	RBR	_	12	advmod	_	_
# 14	,	_	_	,	_	12	punct	_	_
# 15	or	_	_	CC	_	12	cc	_	_
# 16	down	_	_	RB	_	12	advmod	_	_
# 17	about	_	_	RB	_	16	pcomp	_	_
# 18	$	_	_	$	_	17	pobj	_	_
# 19	17.50	_	_	CD	_	18	num	_	_
# 20	for	_	_	IN	_	18	prep	_	_
# 21	each	_	_	DT	_	25	det	_	_
# 22	$	_	_	$	_	25	amod	_	_
# 23	1,000	_	_	CD	_	22	num	_	_
# 24	face	_	_	NN	_	25	nn	_	_
# 25	amount	_	_	NN	_	20	pobj	_	_
# 26	.	_	_	.	_	8	punct	_	_
#
# 1	The	_	_	DT	_	2	det	_	_
# 2	reversal	_	_	NN	_	6	nsubj	_	_
# 3	was	_	_	VBD	_	6	cop	_	_
# 4	even	_	_	RB	_	5	advmod	_	_
# 5	more	_	_	RBR	_	6	amod	_	_
# 6	evident	_	_	JJ	_	0	root	_	_
# 7	among	_	_	IN	_	6	prep	_	_
# 8	shorter-term	_	_	JJ	_	10	amod	_	_
# 9	Treasury	_	_	NNP	_	10	nn	_	_
# 10	securities	_	_	NNS	_	7	pobj	_	_
# 11	.	_	_	.	_	6	punct	_	_
#
# 1	After	_	_	IN	_	5	mark	_	_
# 2	Treasury	_	_	NNP	_	4	nn	_	_
# 3	bill	_	_	NN	_	4	nn	_	_
# 4	rates	_	_	NNS	_	5	nsubj	_	_
# 5	plummeted	_	_	VBD	_	0	root	_	_
# 6	as	_	_	RB	_	16	mark	_	_
# 7	much	_	_	RB	_	16	advmod	_	_
# 8	as	_	_	IN	_	16	mark	_	_
# 9	0.70	_	_	CD	_	11	num	_	_
# 10	percentage	_	_	NN	_	11	nn	_	_
# 11	point	_	_	NN	_	8	pobj	_	_
# 12	on	_	_	IN	_	11	prep	_	_
# 13	Friday	_	_	NNP	_	12	pobj	_	_
# 14	,	_	_	,	_	16	punct	_	_
# 15	they	_	_	PRP	_	16	nsubj	_	_
# 16	gave	_	_	VBD	_	5	conj	_	_
# 17	back	_	_	RB	_	18	amod	_	_
# 18	three-fourths	_	_	JJ	_	16	dobj	_	_
# 19	of	_	_	IN	_	18	prep	_	_
# 20	that	_	_	DT	_	21	det	_	_
# 21	amount	_	_	NN	_	19	pobj	_	_
# 22	yesterday	_	_	NN	_	16	tmod	_	_
# 23	.	_	_	.	_	5	punct	_	_
#
# 1	The	_	_	DT	_	3	det	_	_
# 2	bond-equivalent	_	_	JJ	_	3	amod	_	_
# 3	yield	_	_	NN	_	13	nsubjpass	_	_
# 4	on	_	_	IN	_	3	prep	_	_
# 5	three-month	_	_	JJ	_	7	amod	_	_
# 6	Treasury	_	_	NNP	_	7	nn	_	_
# 7	bills	_	_	NNS	_	4	pobj	_	_
# 8	,	_	_	,	_	13	punct	_	_
# 9	for	_	_	IN	_	13	prep	_	_
# 10	example	_	_	NN	_	9	pobj	_	_
# 11	,	_	_	,	_	13	punct	_	_
# 12	was	_	_	VBD	_	13	auxpass	_	_
# 13	quoted	_	_	VBN	_	0	root	_	_
# 14	late	_	_	JJ	_	13	advmod	_	_
# 15	yesterday	_	_	NN	_	14	nsubj	_	_
# 16	at	_	_	IN	_	15	prep	_	_
# 17	7.72	_	_	CD	_	18	num	_	_
# 18	%	_	_	NN	_	16	pobj	_	_
# 19	,	_	_	,	_	18	punct	_	_
# 20	compared	_	_	VBN	_	18	prep	_	_
# 21	with	_	_	IN	_	20	pcomp	_	_
# 22	7.16	_	_	CD	_	23	num	_	_
# 23	%	_	_	NN	_	21	pobj	_	_
# 24	Friday	_	_	NNP	_	23	conj	_	_
# 25	.	_	_	.	_	13	punct	_	_
#
# 1	Investment-grade	_	_	JJ	_	3	amod	_	_
# 2	corporate	_	_	JJ	_	3	amod	_	_
# 3	bonds	_	_	NNS	_	0	root	_	_
# 4	,	_	_	,	_	3	punct	_	_
# 5	mortgage-backed	_	_	JJ	_	6	amod	_	_
# 6	securities	_	_	NNS	_	9	nn	_	_
# 7	and	_	_	CC	_	6	cc	_	_
# 8	municipal	_	_	JJ	_	9	amod	_	_
# 9	bonds	_	_	NNS	_	3	conj	_	_
# 10	also	_	_	RB	_	11	advmod	_	_
# 11	fell	_	_	VBD	_	9	rcmod	_	_
# 12	.	_	_	.	_	3	punct	_	_
#
# 1	But	_	_	CC	_	16	cc	_	_
# 2	prices	_	_	NNS	_	16	nsubj	_	_
# 3	of	_	_	IN	_	2	prep	_	_
# 4	junk	_	_	NN	_	5	nn	_	_
# 5	bonds	_	_	NNS	_	3	pobj	_	_
# 6	,	_	_	,	_	5	punct	_	_
# 7	which	_	_	WDT	_	9	nsubj	_	_
# 8	were	_	_	VBD	_	9	aux	_	_
# 9	battered	_	_	VBN	_	5	vmod	_	_
# 10	Friday	_	_	NNP	_	9	dobj	_	_
# 11	in	_	_	IN	_	9	prep	_	_
# 12	near	_	_	JJ	_	11	pobj	_	_
# 13	standstill	_	_	JJ	_	14	nn	_	_
# 14	trading	_	_	NN	_	12	pobj	_	_
# 15	,	_	_	,	_	2	punct	_	_
# 16	rebounded	_	_	VBD	_	0	root	_	_
# 17	to	_	_	TO	_	16	prep	_	_
# 18	post	_	_	VB	_	17	pobj	_	_
# 19	small	_	_	JJ	_	20	amod	_	_
# 20	gains	_	_	NNS	_	18	conj	_	_
# 21	after	_	_	IN	_	20	prep	_	_
# 22	a	_	_	DT	_	25	det	_	_
# 23	volatile	_	_	JJ	_	25	amod	_	_
# 24	trading	_	_	NN	_	25	nn	_	_
# 25	session	_	_	NN	_	21	pobj	_	_
# 26	.	_	_	.	_	16	punct	_	_
#
# 1	Junk	_	_	NN	_	2	nn	_	_
# 2	bonds	_	_	NNS	_	3	nsubj	_	_
# 3	opened	_	_	VBD	_	0	root	_	_
# 4	as	_	_	RB	_	9	mark	_	_
# 5	much	_	_	RB	_	6	advmod	_	_
# 6	as	_	_	IN	_	9	advmod	_	_
# 7	four	_	_	CD	_	8	num	_	_
# 8	points	_	_	NNS	_	9	npadvmod	_	_
# 9	lower	_	_	RBR	_	3	advmod	_	_
# 10	but	_	_	CC	_	9	cc	_	_
# 11	staged	_	_	VBD	_	9	conj	_	_
# 12	a	_	_	DT	_	14	det	_	_
# 13	modest	_	_	JJ	_	14	amod	_	_
# 14	comeback	_	_	NN	_	11	dobj	_	_
# 15	as	_	_	IN	_	11	prep	_	_
# 16	stock	_	_	NN	_	15	pobj	_	_
# 17	prices	_	_	NNS	_	16	conj	_	_
# 18	firmed	_	_	VBD	_	16	rcmod	_	_
# 19	.	_	_	.	_	3	punct	_	_
#
# 1	Some	_	_	DT	_	2	det	_	_
# 2	traders	_	_	NNS	_	3	nsubj	_	_
# 3	said	_	_	VBD	_	0	root	_	_
# 4	the	_	_	DT	_	6	det	_	_
# 5	high-yield	_	_	JJ	_	6	amod	_	_
# 6	market	_	_	NN	_	8	nsubj	_	_
# 7	was	_	_	VBD	_	8	auxpass	_	_
# 8	helped	_	_	VBN	_	3	ccomp	_	_
# 9	by	_	_	IN	_	8	prep	_	_
# 10	active	_	_	JJ	_	12	amod	_	_
# 11	institutional	_	_	JJ	_	12	amod	_	_
# 12	buying	_	_	NN	_	9	pcomp	_	_
# 13	.	_	_	.	_	3	punct	_	_
#
# 1	In	_	_	IN	_	5	prep	_	_
# 2	particular	_	_	JJ	_	1	pobj	_	_
# 3	,	_	_	,	_	5	punct	_	_
# 4	they	_	_	PRP	_	5	nsubj	_	_
# 5	said	_	_	VBD	_	0	root	_	_
# 6	,	_	_	,	_	5	punct	_	_
# 7	firms	_	_	NNS	_	5	ccomp	_	_
# 8	such	_	_	JJ	_	9	mwe	_	_
# 9	as	_	_	IN	_	7	prep	_	_
# 10	First	_	_	NNP	_	12	nn	_	_
# 11	Boston	_	_	NNP	_	12	nn	_	_
# 12	Corp.	_	_	NNP	_	17	nn	_	_
# 13	and	_	_	CC	_	12	cc	_	_
# 14	Drexel	_	_	NNP	_	17	nn	_	_
# 15	Burnham	_	_	NNP	_	17	nn	_	_
# 16	Lambert	_	_	NNP	_	17	nn	_	_
# 17	Inc.	_	_	NNP	_	9	pobj	_	_
# 18	began	_	_	VBD	_	17	rcmod	_	_
# 19	making	_	_	VBG	_	18	xcomp	_	_
# 20	a	_	_	DT	_	21	det	_	_
# 21	market	_	_	NN	_	19	dobj	_	_
# 22	in	_	_	IN	_	21	prep	_	_
# 23	junk	_	_	NN	_	24	nn	_	_
# 24	issues	_	_	NNS	_	22	pobj	_	_
# 25	early	_	_	RB	_	24	advmod	_	_
# 26	in	_	_	IN	_	24	prep	_	_
# 27	the	_	_	DT	_	28	det	_	_
# 28	session	_	_	NN	_	26	pobj	_	_
# 29	when	_	_	WRB	_	31	advmod	_	_
# 30	prices	_	_	NNS	_	31	nsubj	_	_
# 31	hit	_	_	VBD	_	28	rcmod	_	_
# 32	severely	_	_	RB	_	33	advmod	_	_
# 33	depressed	_	_	VBN	_	31	conj	_	_
# 34	levels	_	_	NNS	_	33	dobj	_	_
# 35	.	_	_	.	_	5	punct	_	_
#
# 1	``	_	_	``	_	23	punct	_	_
# 2	I	_	_	PRP	_	3	nsubj	_	_
# 3	think	_	_	VBP	_	23	ccomp	_	_
# 4	the	_	_	DT	_	5	det	_	_
# 5	willingness	_	_	NN	_	3	dobj	_	_
# 6	of	_	_	IN	_	5	prep	_	_
# 7	securities	_	_	NNS	_	8	nn	_	_
# 8	companies	_	_	NNS	_	6	pobj	_	_
# 9	to	_	_	TO	_	10	aux	_	_
# 10	make	_	_	VB	_	5	vmod	_	_
# 11	markets	_	_	NNS	_	10	dobj	_	_
# 12	for	_	_	IN	_	11	prep	_	_
# 13	high-yield	_	_	JJ	_	14	amod	_	_
# 14	issues	_	_	NNS	_	12	pobj	_	_
# 15	improved	_	_	VBD	_	17	amod	_	_
# 16	the	_	_	DT	_	17	det	_	_
# 17	sentiment	_	_	NN	_	14	dobj	_	_
# 18	for	_	_	IN	_	17	prep	_	_
# 19	junk	_	_	NN	_	20	nn	_	_
# 20	bonds	_	_	NNS	_	18	pobj	_	_
# 21	,	_	_	,	_	23	punct	_	_
# 22	''	_	_	''	_	23	punct	_	_
# 23	said	_	_	VBD	_	0	root	_	_
# 24	John	_	_	NNP	_	25	nn	_	_
# 25	Lonski	_	_	NNP	_	23	nsubj	_	_
# 26	,	_	_	,	_	25	punct	_	_
# 27	an	_	_	DT	_	28	det	_	_
# 28	economist	_	_	NN	_	25	appos	_	_
# 29	at	_	_	IN	_	28	prep	_	_
# 30	Moody	_	_	NNP	_	34	nn	_	_
# 31	's	_	_	POS	_	30	possessive	_	_
# 32	Investors	_	_	NNP	_	34	nn	_	_
# 33	Service	_	_	NNP	_	34	nn	_	_
# 34	Inc	_	_	NNP	_	29	pobj	_	_
# 35	.	_	_	.	_	23	punct	_	_
#
# 1	U.S.	_	_	NNP	_	3	nn	_	_
# 2	Treasury	_	_	NNP	_	3	nn	_	_
# 3	bonds	_	_	NNS	_	0	root	_	_
# 4	were	_	_	VBD	_	5	cop	_	_
# 5	higher	_	_	JJR	_	3	advmod	_	_
# 6	in	_	_	IN	_	3	prep	_	_
# 7	overnight	_	_	JJ	_	8	amod	_	_
# 8	trading	_	_	NN	_	6	pobj	_	_
# 9	in	_	_	IN	_	13	prep	_	_
# 10	Japan	_	_	NNP	_	13	nsubj	_	_
# 11	,	_	_	,	_	10	punct	_	_
# 12	which	_	_	WDT	_	13	nsubj	_	_
# 13	opened	_	_	VBD	_	8	rcmod	_	_
# 14	at	_	_	IN	_	13	prep	_	_
# 15	about	_	_	RB	_	14	pobj	_	_
# 16	7:30	_	_	CD	_	15	num	_	_
# 17	p.m.	_	_	NN	_	16	advmod	_	_
# 18	EDT	_	_	NNP	_	17	conj	_	_
# 19	.	_	_	.	_	3	punct	_	_
#
# 1	The	_	_	DT	_	4	det	_	_
# 2	benchmark	_	_	NN	_	4	amod	_	_
# 3	30-year	_	_	JJ	_	4	amod	_	_
# 4	bond	_	_	NN	_	8	nsubj	_	_
# 5	,	_	_	,	_	8	punct	_	_
# 6	for	_	_	IN	_	8	prep	_	_
# 7	example	_	_	NN	_	6	pobj	_	_
# 8	rose	_	_	VBD	_	0	root	_	_
# 9	one	_	_	CD	_	10	num	_	_
# 10	point	_	_	NN	_	8	dobj	_	_
# 11	in	_	_	IN	_	8	prep	_	_
# 12	early	_	_	JJ	_	14	amod	_	_
# 13	Japanese	_	_	JJ	_	14	amod	_	_
# 14	trading	_	_	NN	_	11	pobj	_	_
# 15	in	_	_	IN	_	14	prep	_	_
# 16	reaction	_	_	NN	_	15	pobj	_	_
# 17	to	_	_	TO	_	16	prep	_	_
# 18	a	_	_	DT	_	21	det	_	_
# 19	quick	_	_	JJ	_	21	amod	_	_
# 20	600-point	_	_	JJ	_	21	amod	_	_
# 21	drop	_	_	NN	_	17	pobj	_	_
# 22	in	_	_	IN	_	21	prep	_	_
# 23	the	_	_	DT	_	26	det	_	_
# 24	Tokyo	_	_	NNP	_	26	nn	_	_
# 25	stock	_	_	NN	_	26	nn	_	_
# 26	market	_	_	NN	_	22	pobj	_	_
# 27	.	_	_	.	_	8	punct	_	_
#
# 1	But	_	_	CC	_	8	cc	_	_
# 2	as	_	_	IN	_	8	mark	_	_
# 3	Japanese	_	_	JJ	_	4	amod	_	_
# 4	stocks	_	_	NNS	_	8	nsubj	_	_
# 5	rebounded	_	_	VBD	_	4	rcmod	_	_
# 6	,	_	_	,	_	4	punct	_	_
# 7	Treasurys	_	_	NNPS	_	4	conj	_	_
# 8	retreated	_	_	VBD	_	0	root	_	_
# 9	and	_	_	CC	_	8	cc	_	_
# 10	ended	_	_	VBD	_	8	xcomp	_	_
# 11	just	_	_	RB	_	12	advmod	_	_
# 12	modestly	_	_	RB	_	13	advmod	_	_
# 13	higher	_	_	RBR	_	10	advmod	_	_
# 14	.	_	_	.	_	8	punct	_	_
#
# 1	Many	_	_	JJ	_	4	num	_	_
# 2	U.S.	_	_	NNP	_	4	nn	_	_
# 3	trading	_	_	NN	_	4	nn	_	_
# 4	operations	_	_	NNS	_	6	nsubj	_	_
# 5	,	_	_	,	_	4	punct	_	_
# 6	wanting	_	_	VBG	_	0	root	_	_
# 7	to	_	_	TO	_	8	aux	_	_
# 8	keep	_	_	VB	_	6	xcomp	_	_
# 9	a	_	_	DT	_	11	det	_	_
# 10	watchful	_	_	JJ	_	11	amod	_	_
# 11	eye	_	_	NN	_	8	dobj	_	_
# 12	on	_	_	IN	_	11	prep	_	_
# 13	Japanese	_	_	JJ	_	14	amod	_	_
# 14	trading	_	_	NN	_	12	pobj	_	_
# 15	as	_	_	IN	_	14	prep	_	_
# 16	an	_	_	DT	_	17	det	_	_
# 17	indication	_	_	NN	_	15	pobj	_	_
# 18	of	_	_	IN	_	17	prep	_	_
# 19	where	_	_	WRB	_	23	advmod	_	_
# 20	U.S.	_	_	NNP	_	21	nn	_	_
# 21	trading	_	_	NN	_	23	nsubj	_	_
# 22	would	_	_	MD	_	23	aux	_	_
# 23	begin	_	_	VB	_	17	ccomp	_	_
# 24	,	_	_	,	_	6	punct	_	_
# 25	were	_	_	VBD	_	6	xcomp	_	_
# 26	fully	_	_	RB	_	27	advmod	_	_
# 27	staffed	_	_	VBN	_	25	pcomp	_	_
# 28	during	_	_	IN	_	27	prep	_	_
# 29	the	_	_	DT	_	32	det	_	_
# 30	Tokyo	_	_	NNP	_	32	nn	_	_
# 31	trading	_	_	NN	_	32	nn	_	_
# 32	session	_	_	NN	_	28	pobj	_	_
# 33	.	_	_	.	_	6	punct	_	_
#
# 1	``	_	_	``	_	13	punct	_	_
# 2	Most	_	_	JJS	_	6	nsubj	_	_
# 3	of	_	_	IN	_	2	prep	_	_
# 4	the	_	_	DT	_	5	det	_	_
# 5	action	_	_	NN	_	3	pobj	_	_
# 6	was	_	_	VBD	_	13	ccomp	_	_
# 7	during	_	_	IN	_	6	prep	_	_
# 8	the	_	_	DT	_	10	det	_	_
# 9	night	_	_	NN	_	10	nn	_	_
# 10	session	_	_	NN	_	7	pobj	_	_
# 11	,	_	_	,	_	13	punct	_	_
# 12	''	_	_	''	_	13	punct	_	_
# 13	said	_	_	VBD	_	0	root	_	_
# 14	Michael	_	_	NNP	_	15	nn	_	_
# 15	Moore	_	_	NNP	_	17	nn	_	_
# 16	,	_	_	,	_	15	punct	_	_
# 17	trading	_	_	NN	_	13	ccomp	_	_
# 18	manager	_	_	NN	_	17	conj	_	_
# 19	at	_	_	IN	_	18	prep	_	_
# 20	Continental	_	_	NNP	_	21	nn	_	_
# 21	Bank	_	_	NNP	_	19	pobj	_	_
# 22	.	_	_	.	_	13	punct	_	_
#
# 1	Jay	_	_	NNP	_	2	nn	_	_
# 2	Goldinger	_	_	NNP	_	6	nsubj	_	_
# 3	,	_	_	,	_	2	punct	_	_
# 4	who	_	_	WP	_	6	nsubj	_	_
# 5	often	_	_	RB	_	6	advmod	_	_
# 6	trades	_	_	VBZ	_	18	nsubj	_	_
# 7	overnight	_	_	RB	_	6	advmod	_	_
# 8	for	_	_	IN	_	7	prep	_	_
# 9	Capital	_	_	NNP	_	11	nn	_	_
# 10	Insight	_	_	NNP	_	11	nn	_	_
# 11	Inc.	_	_	NNP	_	14	nn	_	_
# 12	,	_	_	,	_	11	punct	_	_
# 13	Beverly	_	_	NNP	_	14	nn	_	_
# 14	Hills	_	_	NNP	_	8	pobj	_	_
# 15	,	_	_	,	_	14	punct	_	_
# 16	Calif.	_	_	NNP	_	14	appos	_	_
# 17	,	_	_	,	_	18	punct	_	_
# 18	said	_	_	VBD	_	0	root	_	_
# 19	trading	_	_	NN	_	25	nsubj	_	_
# 20	in	_	_	IN	_	19	prep	_	_
# 21	Tokyo	_	_	NNP	_	20	pobj	_	_
# 22	was	_	_	VBD	_	25	cop	_	_
# 23	``	_	_	``	_	25	punct	_	_
# 24	very	_	_	RB	_	25	advmod	_	_
# 25	active	_	_	JJ	_	18	ccomp	_	_
# 26	''	_	_	''	_	25	punct	_	_
# 27	but	_	_	CC	_	25	cc	_	_
# 28	highly	_	_	RB	_	29	advmod	_	_
# 29	volatile	_	_	JJ	_	25	conj	_	_
# 30	.	_	_	.	_	18	punct	_	_
#
# 1	``	_	_	``	_	28	punct	_	_
# 2	We	_	_	PRP	_	3	nsubj	_	_
# 3	went	_	_	VBD	_	28	ccomp	_	_
# 4	down	_	_	RB	_	3	advmod	_	_
# 5	3/4	_	_	CD	_	6	num	_	_
# 6	point	_	_	NN	_	4	pobj	_	_
# 7	in	_	_	IN	_	3	prep	_	_
# 8	10	_	_	CD	_	9	num	_	_
# 9	minutes	_	_	NNS	_	7	pobj	_	_
# 10	right	_	_	RB	_	9	advmod	_	_
# 11	before	_	_	IN	_	10	prep	_	_
# 12	lunch	_	_	NN	_	11	pobj	_	_
# 13	,	_	_	,	_	3	punct	_	_
# 14	then	_	_	RB	_	3	advmod	_	_
# 15	after	_	_	IN	_	18	mark	_	_
# 16	lunch	_	_	NN	_	15	pobj	_	_
# 17	we	_	_	PRP	_	18	nsubj	_	_
# 18	went	_	_	VBD	_	3	conj	_	_
# 19	up	_	_	RB	_	18	advmod	_	_
# 20	3/4	_	_	CD	_	21	num	_	_
# 21	point	_	_	NN	_	19	pobj	_	_
# 22	in	_	_	IN	_	18	prep	_	_
# 23	12	_	_	CD	_	24	num	_	_
# 24	minutes	_	_	NNS	_	22	pobj	_	_
# 25	,	_	_	,	_	28	punct	_	_
# 26	''	_	_	''	_	28	punct	_	_
# 27	he	_	_	PRP	_	28	nsubj	_	_
# 28	said	_	_	VBD	_	0	root	_	_
# 29	.	_	_	.	_	28	punct	_	_
#
# 1	In	_	_	IN	_	6	prep	_	_
# 2	Tokyo	_	_	NNP	_	4	nn	_	_
# 3	,	_	_	,	_	2	punct	_	_
# 4	trading	_	_	NN	_	1	pobj	_	_
# 5	is	_	_	VBZ	_	6	auxpass	_	_
# 6	halted	_	_	VBN	_	0	root	_	_
# 7	during	_	_	IN	_	6	prep	_	_
# 8	lunchtime	_	_	NN	_	7	pobj	_	_
# 9	.	_	_	.	_	6	punct	_	_
#
# 1	Tokyo	_	_	NNP	_	4	nsubj	_	_
# 2	's	_	_	POS	_	1	possessive	_	_
# 3	market	_	_	NN	_	4	nsubj	_	_
# 4	turned	_	_	VBD	_	0	root	_	_
# 5	out	_	_	RP	_	4	prt	_	_
# 6	to	_	_	TO	_	4	prep	_	_
# 7	be	_	_	VB	_	10	cop	_	_
# 8	a	_	_	DT	_	10	det	_	_
# 9	bad	_	_	JJ	_	10	amod	_	_
# 10	bellwether	_	_	NN	_	6	pobj	_	_
# 11	for	_	_	IN	_	10	prep	_	_
# 12	U.S.	_	_	NNP	_	13	nn	_	_
# 13	trading	_	_	NN	_	11	pobj	_	_
# 14	.	_	_	.	_	4	punct	_	_
#
# 1	When	_	_	WRB	_	4	advmod	_	_
# 2	the	_	_	DT	_	3	det	_	_
# 3	market	_	_	NN	_	4	nsubj	_	_
# 4	opened	_	_	VBD	_	0	root	_	_
# 5	here	_	_	RB	_	4	advmod	_	_
# 6	,	_	_	,	_	9	punct	_	_
# 7	bonds	_	_	NNS	_	9	nsubj	_	_
# 8	prices	_	_	NNS	_	7	conj	_	_
# 9	fell	_	_	VBD	_	4	conj	_	_
# 10	as	_	_	IN	_	9	prep	_	_
# 11	the	_	_	DT	_	13	det	_	_
# 12	stock	_	_	NN	_	13	nn	_	_
# 13	market	_	_	NN	_	10	pobj	_	_
# 14	regained	_	_	VBD	_	13	rcmod	_	_
# 15	strength	_	_	NN	_	14	dobj	_	_
# 16	.	_	_	.	_	4	punct	_	_
#
# 1	The	_	_	DT	_	3	det	_	_
# 2	bond	_	_	NN	_	3	nn	_	_
# 3	market	_	_	NN	_	5	nsubj	_	_
# 4	's	_	_	POS	_	3	possessive	_	_
# 5	focus	_	_	NN	_	11	nsubj	_	_
# 6	on	_	_	IN	_	5	prep	_	_
# 7	stock	_	_	NN	_	8	nn	_	_
# 8	activity	_	_	NN	_	6	pobj	_	_
# 9	was	_	_	VBD	_	11	cop	_	_
# 10	so	_	_	RB	_	11	advmod	_	_
# 11	strong	_	_	JJ	_	15	ccomp	_	_
# 12	yesterday	_	_	NN	_	11	tmod	_	_
# 13	that	_	_	IN	_	15	nsubj	_	_
# 14	it	_	_	PRP	_	15	nsubj	_	_
# 15	overshadowed	_	_	VBD	_	0	root	_	_
# 16	today	_	_	NN	_	18	tmod	_	_
# 17	's	_	_	POS	_	16	possessive	_	_
# 18	slate	_	_	NN	_	15	dobj	_	_
# 19	of	_	_	IN	_	18	prep	_	_
# 20	economic	_	_	JJ	_	21	amod	_	_
# 21	data	_	_	NNS	_	19	pobj	_	_
# 22	,	_	_	,	_	21	punct	_	_
# 23	which	_	_	WDT	_	24	nsubj	_	_
# 24	includes	_	_	VBZ	_	21	vmod	_	_
# 25	the	_	_	DT	_	26	det	_	_
# 26	government	_	_	NN	_	24	dobj	_	_
# 27	's	_	_	POS	_	26	possessive	_	_
# 28	report	_	_	NN	_	26	conj	_	_
# 29	on	_	_	IN	_	28	prep	_	_
# 30	August	_	_	NNP	_	37	nn	_	_
# 31	U.S.	_	_	NNP	_	33	nn	_	_
# 32	merchandise	_	_	NN	_	33	nn	_	_
# 33	trade	_	_	NN	_	37	nn	_	_
# 34	and	_	_	CC	_	33	cc	_	_
# 35	September	_	_	NNP	_	37	nn	_	_
# 36	industrial	_	_	JJ	_	37	amod	_	_
# 37	production	_	_	NN	_	29	pobj	_	_
# 38	.	_	_	.	_	15	punct	_	_
#
# 1	Industrial	_	_	JJ	_	2	amod	_	_
# 2	production	_	_	NN	_	4	nsubjpass	_	_
# 3	is	_	_	VBZ	_	4	auxpass	_	_
# 4	expected	_	_	VBN	_	0	root	_	_
# 5	to	_	_	TO	_	7	aux	_	_
# 6	have	_	_	VB	_	7	aux	_	_
# 7	declined	_	_	VBN	_	4	xcomp	_	_
# 8	0.2	_	_	CD	_	9	num	_	_
# 9	%	_	_	NN	_	7	dobj	_	_
# 10	,	_	_	,	_	4	punct	_	_
# 11	according	_	_	VBG	_	4	advmod	_	_
# 12	to	_	_	TO	_	11	pcomp	_	_
# 13	a	_	_	DT	_	14	det	_	_
# 14	consensus	_	_	NN	_	12	pobj	_	_
# 15	of	_	_	IN	_	14	prep	_	_
# 16	economists	_	_	NNS	_	15	pobj	_	_
# 17	surveyed	_	_	VBN	_	16	vmod	_	_
# 18	by	_	_	IN	_	17	prep	_	_
# 19	Dow	_	_	NNP	_	23	nn	_	_
# 20	Jones	_	_	NNP	_	23	nn	_	_
# 21	Capital	_	_	NNP	_	23	nn	_	_
# 22	Markets	_	_	NNP	_	23	nn	_	_
# 23	Report	_	_	NNP	_	18	pobj	_	_
# 24	.	_	_	.	_	4	punct	_	_
#
# 1	The	_	_	DT	_	4	det	_	_
# 2	August	_	_	NNP	_	4	nn	_	_
# 3	trade	_	_	NN	_	4	nn	_	_
# 4	deficit	_	_	NN	_	6	nsubjpass	_	_
# 5	is	_	_	VBZ	_	6	auxpass	_	_
# 6	expected	_	_	VBN	_	0	root	_	_
# 7	to	_	_	TO	_	9	aux	_	_
# 8	have	_	_	VB	_	9	aux	_	_
# 9	widened	_	_	VBN	_	6	xcomp	_	_
# 10	to	_	_	TO	_	9	prep	_	_
# 11	$	_	_	$	_	10	pobj	_	_
# 12	9.1	_	_	CD	_	13	number	_	_
# 13	billion	_	_	CD	_	11	num	_	_
# 14	from	_	_	IN	_	9	prep	_	_
# 15	$	_	_	$	_	14	pobj	_	_
# 16	7.58	_	_	CD	_	17	number	_	_
# 17	billion	_	_	CD	_	15	num	_	_
# 18	in	_	_	IN	_	15	prep	_	_
# 19	July	_	_	NNP	_	18	pobj	_	_
# 20	.	_	_	.	_	6	punct	_	_
#
# 1	A	_	_	DT	_	2	det	_	_
# 2	widening	_	_	NN	_	7	ccomp	_	_
# 3	of	_	_	IN	_	2	prep	_	_
# 4	that	_	_	DT	_	5	det	_	_
# 5	magnitude	_	_	NN	_	2	dobj	_	_
# 6	,	_	_	,	_	2	punct	_	_
# 7	said	_	_	VBD	_	0	root	_	_
# 8	one	_	_	CD	_	9	num	_	_
# 9	New	_	_	NNP	_	7	nsubj	_	_
# 10	York	_	_	NNP	_	11	nn	_	_
# 11	trader	_	_	NN	_	9	appos	_	_
# 12	,	_	_	,	_	9	punct	_	_
# 13	is	_	_	VBZ	_	18	cop	_	_
# 14	``	_	_	``	_	18	punct	_	_
# 15	not	_	_	RB	_	18	neg	_	_
# 16	a	_	_	DT	_	18	det	_	_
# 17	favorable	_	_	JJ	_	18	amod	_	_
# 18	number	_	_	NN	_	9	conj	_	_
# 19	...	_	_	:	_	7	punct	_	_
# 20	.	_	_	.	_	7	punct	_	_
#
# 1	It	_	_	PRP	_	3	nsubj	_	_
# 2	could	_	_	MD	_	3	aux	_	_
# 3	do	_	_	VB	_	0	root	_	_
# 4	damage	_	_	NN	_	3	dobj	_	_
# 5	to	_	_	TO	_	3	prep	_	_
# 6	us	_	_	PRP	_	5	pobj	_	_
# 7	.	_	_	.	_	3	punct	_	_
# 8	''	_	_	''	_	3	punct	_	_
#
# 1	Meanwhile	_	_	RB	_	6	advmod	_	_
# 2	,	_	_	,	_	6	punct	_	_
# 3	agency	_	_	NN	_	6	nsubjpass	_	_
# 4	supply	_	_	NN	_	3	appos	_	_
# 5	is	_	_	VBZ	_	6	auxpass	_	_
# 6	expected	_	_	VBN	_	0	root	_	_
# 7	to	_	_	TO	_	8	aux	_	_
# 8	weigh	_	_	VB	_	6	xcomp	_	_
# 9	heavily	_	_	RB	_	8	advmod	_	_
# 10	on	_	_	IN	_	8	prep	_	_
# 11	the	_	_	DT	_	12	det	_	_
# 12	market	_	_	NN	_	10	pobj	_	_
# 13	today	_	_	NN	_	10	pobj	_	_
# 14	when	_	_	WRB	_	25	advmod	_	_
# 15	the	_	_	DT	_	16	det	_	_
# 16	Federal	_	_	NNP	_	20	nn	_	_
# 17	Home	_	_	NNP	_	20	nn	_	_
# 18	Loan	_	_	NNP	_	20	nn	_	_
# 19	Bank	_	_	NNP	_	20	nn	_	_
# 20	prices	_	_	VBZ	_	25	nsubj	_	_
# 21	a	_	_	DT	_	25	det	_	_
# 22	$	_	_	$	_	25	amod	_	_
# 23	2.3	_	_	CD	_	24	number	_	_
# 24	billion	_	_	CD	_	22	num	_	_
# 25	offering	_	_	NN	_	13	appos	_	_
# 26	of	_	_	IN	_	25	prep	_	_
# 27	one-year	_	_	JJ	_	29	amod	_	_
# 28	,	_	_	,	_	27	punct	_	_
# 29	three-year	_	_	JJ	_	26	pobj	_	_
# 30	,	_	_	,	_	29	prep	_	_
# 31	five-year	_	_	JJ	_	34	amod	_	_
# 32	and	_	_	CC	_	31	cc	_	_
# 33	10-year	_	_	JJ	_	34	amod	_	_
# 34	maturities	_	_	NNS	_	30	dobj	_	_
# 35	.	_	_	.	_	6	punct	_	_
#
# 1	Tomorrow	_	_	NN	_	8	tmod	_	_
# 2	,	_	_	,	_	8	punct	_	_
# 3	the	_	_	DT	_	6	det	_	_
# 4	Resolution	_	_	NNP	_	6	nn	_	_
# 5	Funding	_	_	NNP	_	6	nn	_	_
# 6	Corp.	_	_	NNP	_	8	nsubj	_	_
# 7	will	_	_	MD	_	8	aux	_	_
# 8	provide	_	_	VB	_	0	root	_	_
# 9	details	_	_	NNS	_	8	dobj	_	_
# 10	of	_	_	IN	_	9	prep	_	_
# 11	its	_	_	PRP$	_	14	poss	_	_
# 12	first	_	_	JJ	_	14	amod	_	_
# 13	bond	_	_	NN	_	14	nn	_	_
# 14	issue	_	_	NN	_	10	pobj	_	_
# 15	,	_	_	,	_	14	punct	_	_
# 16	which	_	_	WDT	_	18	nsubjpass	_	_
# 17	is	_	_	VBZ	_	18	auxpass	_	_
# 18	expected	_	_	VBN	_	14	rcmod	_	_
# 19	to	_	_	TO	_	18	prep	_	_
# 20	total	_	_	VB	_	19	pobj	_	_
# 21	between	_	_	IN	_	20	prep	_	_
# 22	$	_	_	$	_	21	num	_	_
# 23	4	_	_	CD	_	24	num	_	_
# 24	billion	_	_	CD	_	22	num	_	_
# 25	and	_	_	CC	_	22	cc	_	_
# 26	$	_	_	$	_	22	conj	_	_
# 27	6	_	_	CD	_	28	number	_	_
# 28	billion	_	_	CD	_	26	num	_	_
# 29	and	_	_	CC	_	20	cc	_	_
# 30	carry	_	_	VB	_	20	conj	_	_
# 31	a	_	_	DT	_	32	det	_	_
# 32	maturity	_	_	NN	_	30	dobj	_	_
# 33	greater	_	_	JJR	_	30	conj	_	_
# 34	than	_	_	IN	_	33	prep	_	_
# 35	20	_	_	CD	_	36	num	_	_
# 36	years	_	_	NNS	_	34	pobj	_	_
# 37	.	_	_	.	_	8	punct	_	_
#
# 1	Resolution	_	_	NNP	_	2	nn	_	_
# 2	Funding	_	_	NNP	_	5	nn	_	_
# 3	is	_	_	VBZ	_	5	cop	_	_
# 4	a	_	_	DT	_	5	det	_	_
# 5	division	_	_	NN	_	0	root	_	_
# 6	of	_	_	IN	_	5	prep	_	_
# 7	Resolution	_	_	NNP	_	9	nn	_	_
# 8	Trust	_	_	NNP	_	9	nn	_	_
# 9	Corp.	_	_	NNP	_	6	pobj	_	_
# 10	,	_	_	,	_	9	punct	_	_
# 11	the	_	_	DT	_	14	det	_	_
# 12	new	_	_	JJ	_	14	amod	_	_
# 13	federal	_	_	JJ	_	14	amod	_	_
# 14	agency	_	_	NN	_	9	appos	_	_
# 15	created	_	_	VBN	_	5	vmod	_	_
# 16	to	_	_	TO	_	17	aux	_	_
# 17	bail	_	_	VB	_	15	xcomp	_	_
# 18	out	_	_	RP	_	17	prt	_	_
# 19	the	_	_	DT	_	20	det	_	_
# 20	nation	_	_	NN	_	23	nn	_	_
# 21	's	_	_	POS	_	20	possessive	_	_
# 22	troubled	_	_	VBN	_	23	amod	_	_
# 23	thrifts	_	_	NNS	_	17	dobj	_	_
# 24	.	_	_	.	_	5	punct	_	_
#
# 1	And	_	_	CC	_	8	cc	_	_
# 2	this	_	_	DT	_	3	det	_	_
# 3	week	_	_	NN	_	8	tmod	_	_
# 4	the	_	_	DT	_	7	det	_	_
# 5	Tennessee	_	_	NNP	_	7	nn	_	_
# 6	Valley	_	_	NNP	_	7	nn	_	_
# 7	Authority	_	_	NNP	_	8	nsubj	_	_
# 8	plans	_	_	VBZ	_	0	root	_	_
# 9	to	_	_	TO	_	10	aux	_	_
# 10	price	_	_	VB	_	8	dobj	_	_
# 11	a	_	_	DT	_	15	det	_	_
# 12	$	_	_	$	_	15	amod	_	_
# 13	3	_	_	CD	_	14	number	_	_
# 14	billion	_	_	CD	_	12	num	_	_
# 15	offering	_	_	NN	_	10	conj	_	_
# 16	,	_	_	,	_	15	punct	_	_
# 17	its	_	_	PRP$	_	21	poss	_	_
# 18	first	_	_	JJ	_	21	amod	_	_
# 19	public	_	_	NN	_	21	amod	_	_
# 20	debt	_	_	NN	_	21	nn	_	_
# 21	borrowing	_	_	NN	_	15	dobj	_	_
# 22	in	_	_	IN	_	15	prep	_	_
# 23	15	_	_	CD	_	24	num	_	_
# 24	years	_	_	NNS	_	22	pobj	_	_
# 25	.	_	_	.	_	8	punct	_	_
#
# 1	``	_	_	``	_	13	punct	_	_
# 2	There	_	_	EX	_	3	expl	_	_
# 3	's	_	_	POS	_	13	ccomp	_	_
# 4	lots	_	_	NNS	_	13	nsubj	_	_
# 5	of	_	_	IN	_	4	prep	_	_
# 6	supply	_	_	NN	_	5	pobj	_	_
# 7	,	_	_	,	_	4	punct	_	_
# 8	''	_	_	''	_	4	punct	_	_
# 9	the	_	_	DT	_	12	det	_	_
# 10	New	_	_	NNP	_	12	nn	_	_
# 11	York	_	_	NNP	_	12	nn	_	_
# 12	trader	_	_	NN	_	4	conj	_	_
# 13	said	_	_	VBD	_	0	root	_	_
# 14	.	_	_	.	_	13	punct	_	_
#
# 1	``	_	_	``	_	0	root	_	_
# 2	We	_	_	PRP	_	3	nsubj	_	_
# 3	have	_	_	VBP	_	1	dobj	_	_
# 4	a	_	_	DT	_	5	nsubj	_	_
# 5	couple	_	_	NN	_	3	dobj	_	_
# 6	or	_	_	CC	_	5	cc	_	_
# 7	three	_	_	CD	_	9	num	_	_
# 8	tough	_	_	JJ	_	9	amod	_	_
# 9	weeks	_	_	NNS	_	5	conj	_	_
# 10	coming	_	_	VBG	_	9	vmod	_	_
# 11	.	_	_	.	_	1	punct	_	_
# 12	''	_	_	''	_	11	punct	_	_
#
# 1	Treasury	_	_	NNP	_	2	nn	_	_
# 2	Securities	_	_	NNP	_	0	root	_	_
#
# 1	Prices	_	_	NNP	_	5	nsubj	_	_
# 2	of	_	_	IN	_	1	prep	_	_
# 3	Treasury	_	_	NNP	_	4	nn	_	_
# 4	bonds	_	_	NNS	_	2	pobj	_	_
# 5	tumbled	_	_	VBD	_	0	root	_	_
# 6	in	_	_	IN	_	5	prep	_	_
# 7	moderate	_	_	JJ	_	6	pobj	_	_
# 8	to	_	_	TO	_	5	prep	_	_
# 9	active	_	_	JJ	_	10	amod	_	_
# 10	trading	_	_	NN	_	8	pobj	_	_
# 11	.	_	_	.	_	5	punct	_	_
#
# 1	The	_	_	DT	_	5	det	_	_
# 2	benchmark	_	_	NN	_	5	amod	_	_
# 3	30-year	_	_	JJ	_	5	amod	_	_
# 4	Treasury	_	_	NNP	_	5	nn	_	_
# 5	bond	_	_	NN	_	7	nsubjpass	_	_
# 6	was	_	_	VBD	_	7	auxpass	_	_
# 7	quoted	_	_	VBN	_	0	root	_	_
# 8	late	_	_	RB	_	7	advmod	_	_
# 9	at	_	_	IN	_	8	prep	_	_
# 10	a	_	_	DT	_	11	det	_	_
# 11	price	_	_	NN	_	9	pobj	_	_
# 12	of	_	_	IN	_	11	prep	_	_
# 13	101	_	_	CD	_	14	number	_	_
# 14	19/32	_	_	CD	_	12	pobj	_	_
# 15	,	_	_	,	_	14	punct	_	_
# 16	compared	_	_	VBN	_	14	prep	_	_
# 17	with	_	_	IN	_	16	pcomp	_	_
# 18	a	_	_	DT	_	20	det	_	_
# 19	closing	_	_	NN	_	20	amod	_	_
# 20	price	_	_	NN	_	17	pobj	_	_
# 21	of	_	_	IN	_	20	prep	_	_
# 22	103	_	_	CD	_	24	num	_	_
# 23	12/32	_	_	CD	_	24	num	_	_
# 24	Friday	_	_	NNP	_	21	pobj	_	_
# 25	.	_	_	.	_	7	punct	_	_
#
# 1	The	_	_	DT	_	2	det	_	_
# 2	yield	_	_	NN	_	0	root	_	_
# 3	on	_	_	IN	_	2	prep	_	_
# 4	the	_	_	DT	_	6	det	_	_
# 5	benchmark	_	_	NN	_	6	amod	_	_
# 6	issue	_	_	NN	_	3	pobj	_	_
# 7	rose	_	_	VBD	_	6	rcmod	_	_
# 8	to	_	_	TO	_	7	prep	_	_
# 9	7.97	_	_	CD	_	10	num	_	_
# 10	%	_	_	NN	_	8	pobj	_	_
# 11	from	_	_	IN	_	7	prep	_	_
# 12	7.82	_	_	CD	_	13	num	_	_
# 13	%	_	_	NN	_	11	pobj	_	_
# 14	.	_	_	.	_	2	punct	_	_
#
# 1	The	_	_	DT	_	4	det	_	_
# 2	latest	_	_	JJS	_	4	amod	_	_
# 3	10-year	_	_	JJ	_	4	amod	_	_
# 4	notes	_	_	NNS	_	6	nsubjpass	_	_
# 5	were	_	_	VBD	_	6	auxpass	_	_
# 6	quoted	_	_	VBN	_	0	root	_	_
# 7	late	_	_	RB	_	6	advmod	_	_
# 8	at	_	_	IN	_	7	prep	_	_
# 9	100	_	_	CD	_	10	num	_	_
# 10	3/32	_	_	CD	_	8	pobj	_	_
# 11	for	_	_	IN	_	10	prep	_	_
# 12	a	_	_	DT	_	13	det	_	_
# 13	yield	_	_	NN	_	11	pobj	_	_
# 14	of	_	_	IN	_	13	prep	_	_
# 15	7.97	_	_	CD	_	16	num	_	_
# 16	%	_	_	NN	_	14	pobj	_	_
# 17	,	_	_	,	_	6	punct	_	_
# 18	compared	_	_	VBN	_	6	prep	_	_
# 19	with	_	_	IN	_	18	pcomp	_	_
# 20	101	_	_	CD	_	21	num	_	_
# 21	9/32	_	_	CD	_	19	pobj	_	_
# 22	to	_	_	TO	_	23	aux	_	_
# 23	yield	_	_	VB	_	21	conj	_	_
# 24	7.84	_	_	CD	_	25	num	_	_
# 25	%	_	_	NN	_	23	dobj	_	_
# 26	.	_	_	.	_	6	punct	_	_
#
# 1	Short-term	_	_	JJ	_	3	amod	_	_
# 2	interest	_	_	NN	_	3	nn	_	_
# 3	rates	_	_	NNS	_	4	nsubj	_	_
# 4	fell	_	_	VBD	_	0	root	_	_
# 5	yesterday	_	_	NN	_	4	tmod	_	_
# 6	at	_	_	IN	_	4	prep	_	_
# 7	the	_	_	DT	_	8	det	_	_
# 8	government	_	_	NN	_	13	nn	_	_
# 9	's	_	_	POS	_	8	possessive	_	_
# 10	weekly	_	_	JJ	_	13	amod	_	_
# 11	Treasury	_	_	NNP	_	13	nn	_	_
# 12	bill	_	_	NN	_	13	nn	_	_
# 13	auction	_	_	NN	_	6	pobj	_	_
# 14	.	_	_	.	_	4	punct	_	_
#
# 1	The	_	_	DT	_	4	det	_	_
# 2	average	_	_	JJ	_	4	amod	_	_
# 3	discount	_	_	NN	_	4	nn	_	_
# 4	rate	_	_	NN	_	0	root	_	_
# 5	on	_	_	IN	_	4	prep	_	_
# 6	new	_	_	JJ	_	9	amod	_	_
# 7	three-month	_	_	JJ	_	9	amod	_	_
# 8	Treasury	_	_	NNP	_	9	nn	_	_
# 9	bills	_	_	NNS	_	5	pobj	_	_
# 10	was	_	_	VBD	_	12	cop	_	_
# 11	7.37	_	_	CD	_	12	num	_	_
# 12	%	_	_	NN	_	4	conj	_	_
# 13	,	_	_	,	_	12	punct	_	_
# 14	the	_	_	DT	_	15	det	_	_
# 15	lowest	_	_	JJS	_	12	conj	_	_
# 16	since	_	_	IN	_	15	prep	_	_
# 17	the	_	_	DT	_	18	det	_	_
# 18	average	_	_	NN	_	16	pobj	_	_
# 19	of	_	_	IN	_	18	prep	_	_
# 20	7.36	_	_	CD	_	21	num	_	_
# 21	%	_	_	NN	_	19	pobj	_	_
# 22	at	_	_	IN	_	15	prep	_	_
# 23	the	_	_	DT	_	24	det	_	_
# 24	auction	_	_	NN	_	22	pobj	_	_
# 25	on	_	_	IN	_	24	prep	_	_
# 26	Oct.	_	_	NNP	_	25	pobj	_	_
# 27	17	_	_	CD	_	26	num	_	_
# 28	,	_	_	,	_	26	punct	_	_
# 29	1988	_	_	CD	_	26	num	_	_
# 30	.	_	_	.	_	4	punct	_	_
#
# 1	The	_	_	DT	_	4	det	_	_
# 2	average	_	_	JJ	_	4	amod	_	_
# 3	discount	_	_	NN	_	4	nn	_	_
# 4	rate	_	_	NN	_	0	root	_	_
# 5	was	_	_	VBD	_	7	cop	_	_
# 6	7.42	_	_	CD	_	7	num	_	_
# 7	%	_	_	NN	_	4	conj	_	_
# 8	on	_	_	IN	_	7	prep	_	_
# 9	new	_	_	JJ	_	11	amod	_	_
# 10	six-month	_	_	JJ	_	11	amod	_	_
# 11	bills	_	_	NNS	_	8	pobj	_	_
# 12	,	_	_	,	_	7	punct	_	_
# 13	the	_	_	DT	_	14	det	_	_
# 14	lowest	_	_	JJS	_	7	conj	_	_
# 15	since	_	_	IN	_	14	prep	_	_
# 16	the	_	_	DT	_	17	det	_	_
# 17	average	_	_	NN	_	15	pobj	_	_
# 18	of	_	_	IN	_	17	prep	_	_
# 19	7.35	_	_	CD	_	20	num	_	_
# 20	%	_	_	NN	_	18	pobj	_	_
# 21	at	_	_	IN	_	14	prep	_	_
# 22	the	_	_	DT	_	23	det	_	_
# 23	auction	_	_	NN	_	21	pobj	_	_
# 24	on	_	_	IN	_	23	prep	_	_
# 25	July	_	_	NNP	_	24	pobj	_	_
# 26	31	_	_	CD	_	25	num	_	_
# 27	,	_	_	,	_	25	punct	_	_
# 28	1989	_	_	CD	_	25	num	_	_
# 29	.	_	_	.	_	4	punct	_	_
#
# 1	Here	_	_	RB	_	0	root	_	_
# 2	are	_	_	VBP	_	3	auxpass	_	_
# 3	auction	_	_	NN	_	1	pobj	_	_
# 4	details	_	_	NNS	_	3	conj	_	_
# 5	:	_	_	:	_	1	punct	_	_
#
# 1	Rates	_	_	NNS	_	3	nsubjpass	_	_
# 2	are	_	_	VBP	_	3	auxpass	_	_
# 3	determined	_	_	VBN	_	0	root	_	_
# 4	by	_	_	IN	_	3	prep	_	_
# 5	the	_	_	DT	_	6	det	_	_
# 6	difference	_	_	NN	_	4	pobj	_	_
# 7	between	_	_	IN	_	6	prep	_	_
# 8	the	_	_	DT	_	10	det	_	_
# 9	purchase	_	_	NN	_	10	nn	_	_
# 10	price	_	_	NN	_	7	pobj	_	_
# 11	and	_	_	CC	_	10	cc	_	_
# 12	face	_	_	NN	_	10	conj	_	_
# 13	value	_	_	NN	_	12	dobj	_	_
# 14	.	_	_	.	_	3	punct	_	_
#
# 1	Thus	_	_	RB	_	5	advmod	_	_
# 2	,	_	_	,	_	5	punct	_	_
# 3	higher	_	_	JJR	_	4	amod	_	_
# 4	bidding	_	_	NN	_	5	nsubj	_	_
# 5	narrows	_	_	VBZ	_	0	root	_	_
# 6	the	_	_	DT	_	7	det	_	_
# 7	investor	_	_	NN	_	9	nn	_	_
# 8	's	_	_	POS	_	7	possessive	_	_
# 9	return	_	_	NN	_	5	dobj	_	_
# 10	while	_	_	IN	_	13	mark	_	_
# 11	lower	_	_	JJR	_	12	amod	_	_
# 12	bidding	_	_	NN	_	13	nsubj	_	_
# 13	widens	_	_	VBZ	_	5	conj	_	_
# 14	it	_	_	PRP	_	13	dobj	_	_
# 15	.	_	_	.	_	5	punct	_	_
#
# 1	The	_	_	DT	_	3	det	_	_
# 2	percentage	_	_	NN	_	3	nn	_	_
# 3	rates	_	_	NNS	_	5	nsubjpass	_	_
# 4	are	_	_	VBP	_	5	auxpass	_	_
# 5	calculated	_	_	VBN	_	0	root	_	_
# 6	on	_	_	IN	_	5	prep	_	_
# 7	a	_	_	DT	_	9	det	_	_
# 8	360-day	_	_	JJ	_	9	amod	_	_
# 9	year	_	_	NN	_	6	pobj	_	_
# 10	,	_	_	,	_	5	punct	_	_
# 11	while	_	_	IN	_	16	mark	_	_
# 12	the	_	_	DT	_	14	det	_	_
# 13	coupon-equivalent	_	_	JJ	_	14	amod	_	_
# 14	yield	_	_	NN	_	16	nsubjpass	_	_
# 15	is	_	_	VBZ	_	16	auxpass	_	_
# 16	based	_	_	VBN	_	5	nsubj	_	_
# 17	on	_	_	IN	_	16	pcomp	_	_
# 18	a	_	_	DT	_	20	det	_	_
# 19	365-day	_	_	JJ	_	20	amod	_	_
# 20	year	_	_	NN	_	17	pobj	_	_
# 21	.	_	_	.	_	5	punct	_	_
#
# 1	Both	_	_	DT	_	2	nsubj	_	_
# 2	issues	_	_	NNS	_	4	nsubjpass	_	_
# 3	are	_	_	VBP	_	4	auxpass	_	_
# 4	dated	_	_	VBN	_	0	root	_	_
# 5	Oct.	_	_	NNP	_	4	tmod	_	_
# 6	19	_	_	CD	_	5	num	_	_
# 7	.	_	_	.	_	4	punct	_	_
#
# 1	The	_	_	DT	_	3	det	_	_
# 2	13-week	_	_	JJ	_	3	amod	_	_
# 3	bills	_	_	NNS	_	4	nsubj	_	_
# 4	mature	_	_	VBP	_	0	root	_	_
# 5	Jan.	_	_	NN	_	4	conj	_	_
# 6	18	_	_	CD	_	5	num	_	_
# 7	,	_	_	,	_	5	punct	_	_
# 8	1990	_	_	CD	_	5	num	_	_
# 9	,	_	_	,	_	4	punct	_	_
# 10	and	_	_	CC	_	4	cc	_	_
# 11	the	_	_	DT	_	13	det	_	_
# 12	26-week	_	_	JJ	_	13	amod	_	_
# 13	bills	_	_	NNS	_	14	nsubj	_	_
# 14	mature	_	_	VBP	_	4	conj	_	_
# 15	April	_	_	NNP	_	14	tmod	_	_
# 16	19	_	_	CD	_	15	num	_	_
# 17	,	_	_	,	_	15	punct	_	_
# 18	1990	_	_	CD	_	15	num	_	_
# 19	.	_	_	.	_	4	punct	_	_
#
# 1	Corporate	_	_	JJ	_	2	amod	_	_
# 2	Issues	_	_	NNS	_	0	root	_	_
#
# 1	Investment-grade	_	_	JJ	_	3	amod	_	_
# 2	corporate	_	_	JJ	_	3	amod	_	_
# 3	bonds	_	_	NNS	_	4	nsubj	_	_
# 4	ended	_	_	VBD	_	0	root	_	_
# 5	one	_	_	CD	_	4	dobj	_	_
# 6	to	_	_	TO	_	4	prep	_	_
# 7	1	_	_	CD	_	8	number	_	_
# 8	1/2	_	_	CD	_	9	num	_	_
# 9	point	_	_	NN	_	6	pobj	_	_
# 10	lower	_	_	RBR	_	9	advmod	_	_
# 11	.	_	_	.	_	4	punct	_	_
#
# 1	There	_	_	EX	_	2	expl	_	_
# 2	were	_	_	VBD	_	0	root	_	_
# 3	no	_	_	DT	_	5	neg	_	_
# 4	new	_	_	JJ	_	5	amod	_	_
# 5	issues	_	_	NNS	_	2	ccomp	_	_
# 6	.	_	_	.	_	2	punct	_	_
#
# 1	Foreign	_	_	JJ	_	2	amod	_	_
# 2	Bonds	_	_	NNS	_	0	root	_	_
#
# 1	Foreign	_	_	JJ	_	2	amod	_	_
# 2	bonds	_	_	NNS	_	3	nsubj	_	_
# 3	surged	_	_	VBD	_	0	root	_	_
# 4	as	_	_	IN	_	7	mark	_	_
# 5	the	_	_	DT	_	6	det	_	_
# 6	dollar	_	_	NN	_	7	nsubj	_	_
# 7	weakened	_	_	VBD	_	3	conj	_	_
# 8	against	_	_	IN	_	7	prep	_	_
# 9	most	_	_	JJS	_	11	amod	_	_
# 10	major	_	_	JJ	_	11	amod	_	_
# 11	currencies	_	_	NNS	_	8	pobj	_	_
# 12	.	_	_	.	_	3	punct	_	_
#
# 1	Among	_	_	IN	_	0	root	_	_
# 2	benchmark	_	_	NN	_	3	amod	_	_
# 3	issues	_	_	NNS	_	1	pobj	_	_
# 4	:	_	_	:	_	1	punct	_	_
# 5	--	_	_	:	_	6	punct	_	_
# 6	Japan	_	_	NNP	_	12	nn	_	_
# 7	's	_	_	POS	_	6	possessive	_	_
# 8	No.	_	_	NN	_	12	nn	_	_
# 9	111	_	_	CD	_	12	num	_	_
# 10	4.6	_	_	CD	_	12	num	_	_
# 11	%	_	_	NN	_	12	amod	_	_
# 12	bond	_	_	NN	_	1	pobj	_	_
# 13	due	_	_	JJ	_	12	amod	_	_
# 14	1998	_	_	CD	_	13	dobj	_	_
# 15	ended	_	_	VBD	_	14	rcmod	_	_
# 16	on	_	_	IN	_	15	prep	_	_
# 17	brokers	_	_	NNS	_	18	nn	_	_
# 18	screens	_	_	NNS	_	16	pobj	_	_
# 19	at	_	_	IN	_	15	prep	_	_
# 20	96.15	_	_	CD	_	19	pobj	_	_
# 21	,	_	_	,	_	15	punct	_	_
# 22	up	_	_	RB	_	15	advmod	_	_
# 23	1.17	_	_	CD	_	24	num	_	_
# 24	point	_	_	NN	_	22	pobj	_	_
# 25	.	_	_	.	_	14	punct	_	_
#
# 1	The	_	_	DT	_	2	det	_	_
# 2	yield	_	_	NN	_	0	root	_	_
# 3	was	_	_	VBD	_	5	cop	_	_
# 4	5.245	_	_	CD	_	5	num	_	_
# 5	%	_	_	NN	_	2	dobj	_	_
# 6	.	_	_	.	_	2	punct	_	_
#
# 1	--	_	_	:	_	3	punct	_	_
# 2	West	_	_	NNP	_	3	nn	_	_
# 3	Germany	_	_	NNP	_	0	root	_	_
# 4	's	_	_	POS	_	3	possessive	_	_
# 5	6	_	_	CD	_	7	number	_	_
# 6	3/4	_	_	CD	_	7	number	_	_
# 7	%	_	_	NN	_	3	conj	_	_
# 8	issue	_	_	NN	_	7	conj	_	_
# 9	due	_	_	JJ	_	8	amod	_	_
# 10	June	_	_	NNP	_	9	tmod	_	_
# 11	1999	_	_	CD	_	10	num	_	_
# 12	ended	_	_	VBD	_	8	vmod	_	_
# 13	at	_	_	IN	_	12	prep	_	_
# 14	98.30	_	_	CD	_	13	pobj	_	_
# 15	,	_	_	,	_	8	punct	_	_
# 16	up	_	_	RB	_	8	advmod	_	_
# 17	0.91	_	_	CD	_	18	num	_	_
# 18	point	_	_	NN	_	16	pobj	_	_
# 19	to	_	_	TO	_	20	aux	_	_
# 20	yield	_	_	VB	_	8	rcmod	_	_
# 21	6.99	_	_	CD	_	22	num	_	_
# 22	%	_	_	NN	_	20	dobj	_	_
# 23	.	_	_	.	_	3	punct	_	_
#
# 1	--	_	_	:	_	27	punct	_	_
# 2	Britain	_	_	NNP	_	7	nn	_	_
# 3	's	_	_	POS	_	2	possessive	_	_
# 4	11	_	_	CD	_	7	num	_	_
# 5	3/4	_	_	CD	_	6	number	_	_
# 6	%	_	_	NN	_	7	amod	_	_
# 7	bond	_	_	NN	_	27	nn	_	_
# 8	due	_	_	JJ	_	7	amod	_	_
# 9	2003/2007	_	_	CD	_	8	dobj	_	_
# 10	ended	_	_	VBD	_	9	rcmod	_	_
# 11	1	_	_	CD	_	12	number	_	_
# 12	1/8	_	_	CD	_	10	advmod	_	_
# 13	higher	_	_	RBR	_	12	advmod	_	_
# 14	at	_	_	IN	_	10	prep	_	_
# 15	111	_	_	CD	_	16	num	_	_
# 16	19/32	_	_	CD	_	14	pobj	_	_
# 17	to	_	_	TO	_	18	aux	_	_
# 18	yield	_	_	VB	_	10	conj	_	_
# 19	10.12	_	_	CD	_	20	num	_	_
# 20	%	_	_	NN	_	18	dobj	_	_
# 21	,	_	_	,	_	27	punct	_	_
# 22	while	_	_	IN	_	27	mark	_	_
# 23	the	_	_	DT	_	27	det	_	_
# 24	11	_	_	CD	_	26	number	_	_
# 25	3/4	_	_	CD	_	26	number	_	_
# 26	%	_	_	NN	_	27	amod	_	_
# 27	notes	_	_	NNS	_	0	root	_	_
# 28	due	_	_	JJ	_	27	amod	_	_
# 29	1991	_	_	CD	_	28	tmod	_	_
# 30	rose	_	_	VBD	_	29	rcmod	_	_
# 31	21/32	_	_	CD	_	30	conj	_	_
# 32	to	_	_	TO	_	30	prep	_	_
# 33	98	_	_	CD	_	34	num	_	_
# 34	26/32	_	_	CD	_	32	pobj	_	_
# 35	to	_	_	TO	_	36	aux	_	_
# 36	yield	_	_	VB	_	30	dobj	_	_
# 37	12.74	_	_	CD	_	38	num	_	_
# 38	%	_	_	NN	_	36	dobj	_	_
# 39	.	_	_	.	_	27	punct	_	_
#
# 1	Mortgage-Backed	_	_	JJ	_	2	amod	_	_
# 2	Securities	_	_	NNS	_	0	root	_	_
#
# 1	Mortgage	_	_	NN	_	2	nn	_	_
# 2	securities	_	_	NNS	_	3	nsubj	_	_
# 3	gave	_	_	VBD	_	0	root	_	_
# 4	up	_	_	RP	_	3	prt	_	_
# 5	most	_	_	JJS	_	3	dobj	_	_
# 6	of	_	_	IN	_	5	prep	_	_
# 7	Friday	_	_	NNP	_	9	nn	_	_
# 8	's	_	_	POS	_	7	possessive	_	_
# 9	gains	_	_	NNS	_	6	pobj	_	_
# ...
# 26	certificate	_	_	NN	_	23	dobj	_	_
# 27	of	_	_	IN	_	26	prep	_	_
# 28	any	_	_	DT	_	29	det	_	_
# 29	carrier	_	_	NN	_	31	nn	_	_
# 30	the	_	_	DT	_	31	det	_	_
# 31	official	_	_	NN	_	27	pobj	_	_
# 32	considers	_	_	VBZ	_	31	rcmod	_	_
# 33	unfit	_	_	JJ	_	32	xcomp	_	_
# 34	.	_	_	.	_	8	punct	_	_
#
# 1	Supporters	_	_	NNS	_	23	nsubj	_	_
# 2	of	_	_	IN	_	1	prep	_	_
# 3	the	_	_	DT	_	4	det	_	_
# 4	legislation	_	_	NN	_	2	pobj	_	_
# 5	view	_	_	VBP	_	4	conj	_	_
# 6	the	_	_	DT	_	7	det	_	_
# 7	bill	_	_	NN	_	5	dobj	_	_
# 8	as	_	_	IN	_	5	prep	_	_
# 9	an	_	_	DT	_	10	det	_	_
# 10	effort	_	_	NN	_	8	pobj	_	_
# 11	to	_	_	TO	_	12	aux	_	_
# 12	add	_	_	VB	_	10	vmod	_	_
# 13	stability	_	_	NN	_	12	dobj	_	_
# 14	and	_	_	CC	_	10	cc	_	_
# 15	certainty	_	_	NN	_	10	vmod	_	_
# 16	to	_	_	TO	_	15	prep	_	_
# 17	the	_	_	DT	_	19	det	_	_
# 18	airline-acquisition	_	_	JJ	_	19	amod	_	_
# 19	process	_	_	NN	_	16	pobj	_	_
# 20	,	_	_	,	_	1	punct	_	_
# 21	and	_	_	CC	_	1	cc	_	_
# 22	to	_	_	TO	_	23	aux	_	_
# 23	preserve	_	_	VB	_	0	root	_	_
# 24	the	_	_	DT	_	25	det	_	_
# 25	safety	_	_	NN	_	23	dobj	_	_
# 26	and	_	_	CC	_	23	cc	_	_
# 27	fitness	_	_	NN	_	23	dobj	_	_
# 28	of	_	_	IN	_	27	prep	_	_
# 29	the	_	_	DT	_	30	det	_	_
# 30	industry	_	_	NN	_	28	pobj	_	_
# 31	.	_	_	.	_	23	punct	_	_
#
# 1	In	_	_	IN	_	7	prep	_	_
# 2	general	_	_	JJ	_	1	pobj	_	_
# 3	,	_	_	,	_	7	punct	_	_
# 4	the	_	_	DT	_	5	det	_	_
# 5	bill	_	_	NN	_	7	nsubj	_	_
# 6	would	_	_	MD	_	7	aux	_	_
# 7	give	_	_	VB	_	0	root	_	_
# 8	the	_	_	DT	_	9	det	_	_
# 9	Transportation	_	_	NNP	_	10	nn	_	_
# 10	Department	_	_	NNP	_	14	nn	_	_
# 11	a	_	_	DT	_	14	det	_	_
# 12	30-day	_	_	JJ	_	14	amod	_	_
# 13	review	_	_	NN	_	14	nn	_	_
# 14	period	_	_	NN	_	7	dobj	_	_
# 15	before	_	_	IN	_	7	prep	_	_
# 16	15	_	_	CD	_	17	num	_	_
# 17	%	_	_	NN	_	15	pobj	_	_
# 18	or	_	_	CC	_	17	cc	_	_
# 19	more	_	_	JJR	_	17	advmod	_	_
# 20	of	_	_	IN	_	19	prep	_	_
# 21	the	_	_	DT	_	23	det	_	_
# 22	voting	_	_	NN	_	23	amod	_	_
# 23	stock	_	_	NN	_	20	pobj	_	_
# 24	of	_	_	IN	_	23	prep	_	_
# 25	a	_	_	DT	_	29	det	_	_
# 26	major	_	_	JJ	_	29	amod	_	_
# 27	U.S.	_	_	NNP	_	29	nn	_	_
# 28	air	_	_	NN	_	29	nn	_	_
# 29	carrier	_	_	NN	_	24	pobj	_	_
# 30	could	_	_	MD	_	32	aux	_	_
# 31	be	_	_	VB	_	32	auxpass	_	_
# 32	acquired	_	_	VBN	_	17	rcmod	_	_
# 33	.	_	_	.	_	7	punct	_	_
#
# 1	It	_	_	PRP	_	4	nsubj	_	_
# 2	also	_	_	RB	_	4	advmod	_	_
# 3	would	_	_	MD	_	4	aux	_	_
# 4	require	_	_	VB	_	0	root	_	_
# 5	the	_	_	DT	_	6	nsubj	_	_
# 6	acquiring	_	_	VBG	_	4	xcomp	_	_
# 7	party	_	_	NN	_	6	dobj	_	_
# 8	to	_	_	TO	_	9	aux	_	_
# 9	notify	_	_	VB	_	6	dobj	_	_
# 10	the	_	_	DT	_	12	det	_	_
# 11	transportation	_	_	NN	_	12	nn	_	_
# 12	secretary	_	_	NN	_	9	dobj	_	_
# 13	and	_	_	CC	_	9	cc	_	_
# 14	to	_	_	TO	_	15	aux	_	_
# 15	provide	_	_	VB	_	9	xcomp	_	_
# 16	all	_	_	DT	_	17	det	_	_
# 17	information	_	_	NN	_	15	dobj	_	_
# 18	relevant	_	_	JJ	_	17	rcmod	_	_
# 19	to	_	_	TO	_	20	aux	_	_
# 20	determining	_	_	VBG	_	18	conj	_	_
# 21	the	_	_	DT	_	22	det	_	_
# 22	intent	_	_	NN	_	20	dobj	_	_
# 23	of	_	_	IN	_	22	prep	_	_
# 24	the	_	_	DT	_	25	det	_	_
# 25	acquisition	_	_	NN	_	23	pobj	_	_
# 26	.	_	_	.	_	4	punct	_	_
#
# 1	The	_	_	DT	_	2	det	_	_
# 2	bill	_	_	NN	_	0	root	_	_
# 3	would	_	_	MD	_	4	aux	_	_
# 4	allow	_	_	VB	_	2	vmod	_	_
# 5	the	_	_	DT	_	6	det	_	_
# 6	secretary	_	_	NN	_	4	dobj	_	_
# 7	to	_	_	TO	_	8	aux	_	_
# 8	reject	_	_	VB	_	4	xcomp	_	_
# 9	a	_	_	DT	_	10	det	_	_
# 10	buy-out	_	_	NN	_	8	dobj	_	_
# 11	if	_	_	IN	_	17	mark	_	_
# 12	sufficient	_	_	JJ	_	13	amod	_	_
# 13	information	_	_	NN	_	17	nsubjpass	_	_
# 14	has	_	_	VBZ	_	17	aux	_	_
# 15	n't	_	_	RB	_	17	neg	_	_
# 16	been	_	_	VBN	_	17	auxpass	_	_
# 17	provided	_	_	VBN	_	8	conj	_	_
# 18	,	_	_	,	_	17	punct	_	_
# 19	or	_	_	CC	_	17	cc	_	_
# 20	if	_	_	IN	_	24	mark	_	_
# 21	the	_	_	DT	_	22	det	_	_
# 22	buy-out	_	_	NN	_	24	nsubj	_	_
# 23	is	_	_	VBZ	_	24	cop	_	_
# 24	likely	_	_	JJ	_	17	conj	_	_
# 25	to	_	_	TO	_	26	aux	_	_
# 26	weaken	_	_	VB	_	24	conj	_	_
# 27	the	_	_	DT	_	28	det	_	_
# 28	carrier	_	_	NN	_	26	dobj	_	_
# 29	financially	_	_	RB	_	28	advmod	_	_
# 30	,	_	_	,	_	26	punct	_	_
# 31	result	_	_	VB	_	26	dobj	_	_
# 32	in	_	_	IN	_	31	prep	_	_
# 33	a	_	_	DT	_	35	det	_	_
# 34	substantial	_	_	JJ	_	35	amod	_	_
# 35	reduction	_	_	NN	_	32	pobj	_	_
# 36	in	_	_	IN	_	35	prep	_	_
# 37	size	_	_	NN	_	36	pobj	_	_
# 38	of	_	_	IN	_	37	prep	_	_
# 39	the	_	_	DT	_	40	det	_	_
# 40	airline	_	_	NN	_	38	pobj	_	_
# 41	through	_	_	IN	_	40	prep	_	_
# 42	disposal	_	_	NN	_	41	pobj	_	_
# 43	of	_	_	IN	_	42	prep	_	_
# 44	assets	_	_	NNS	_	43	pobj	_	_
# 45	,	_	_	,	_	40	punct	_	_
# 46	or	_	_	CC	_	40	cc	_	_
# 47	give	_	_	VB	_	40	vmod	_	_
# 48	control	_	_	NN	_	47	dobj	_	_
# 49	to	_	_	TO	_	47	prep	_	_
# 50	a	_	_	DT	_	52	det	_	_
# 51	foreign	_	_	JJ	_	52	amod	_	_
# 52	interest	_	_	NN	_	49	pobj	_	_
# 53	.	_	_	.	_	2	punct	_	_
#
# 1	If	_	_	IN	_	5	mark	_	_
# 2	more	_	_	JJR	_	3	amod	_	_
# 3	information	_	_	NN	_	5	nsubjpass	_	_
# 4	is	_	_	VBZ	_	5	auxpass	_	_
# 5	needed	_	_	VBN	_	0	root	_	_
# 6	,	_	_	,	_	10	punct	_	_
# 7	the	_	_	DT	_	8	det	_	_
# 8	secretary	_	_	NN	_	10	nsubj	_	_
# 9	would	_	_	MD	_	10	aux	_	_
# 10	have	_	_	VB	_	5	xcomp	_	_
# 11	authority	_	_	NN	_	10	dobj	_	_
# 12	to	_	_	TO	_	13	aux	_	_
# 13	extend	_	_	VB	_	11	vmod	_	_
# 14	the	_	_	DT	_	16	det	_	_
# 15	review	_	_	NN	_	16	nn	_	_
# 16	period	_	_	NN	_	13	dobj	_	_
# 17	20	_	_	CD	_	18	num	_	_
# 18	days	_	_	NNS	_	16	conj	_	_
# 19	.	_	_	.	_	5	punct	_	_
#
# 1	All	_	_	DT	_	3	det	_	_
# 2	the	_	_	DT	_	3	det	_	_
# 3	witnesses	_	_	NNS	_	11	nsubj	_	_
# 4	,	_	_	,	_	3	punct	_	_
# 5	both	_	_	DT	_	9	det	_	_
# 6	congressmen	_	_	NNS	_	5	advmod	_	_
# 7	and	_	_	CC	_	5	cc	_	_
# 8	industry	_	_	NN	_	9	nn	_	_
# 9	experts	_	_	NNS	_	3	appos	_	_
# 10	,	_	_	,	_	3	punct	_	_
# 11	expressed	_	_	VBD	_	0	root	_	_
# 12	support	_	_	NN	_	11	dobj	_	_
# 13	for	_	_	IN	_	12	prep	_	_
# 14	the	_	_	DT	_	15	det	_	_
# 15	bill	_	_	NN	_	13	pobj	_	_
# 16	in	_	_	IN	_	15	prep	_	_
# 17	order	_	_	NN	_	16	pobj	_	_
# 18	to	_	_	TO	_	19	aux	_	_
# 19	prevent	_	_	VB	_	17	rcmod	_	_
# 20	profiteers	_	_	NNS	_	19	dobj	_	_
# 21	from	_	_	IN	_	20	prep	_	_
# 22	cashing	_	_	VBG	_	21	pobj	_	_
# 23	in	_	_	RP	_	22	prep	_	_
# 24	on	_	_	IN	_	22	prep	_	_
# 25	airline	_	_	NN	_	26	nn	_	_
# 26	profits	_	_	NNS	_	24	pobj	_	_
# 27	at	_	_	IN	_	26	prep	_	_
# 28	the	_	_	DT	_	29	det	_	_
# 29	expense	_	_	NN	_	27	pobj	_	_
# 30	of	_	_	IN	_	29	prep	_	_
# 31	safe	_	_	JJ	_	34	amod	_	_
# 32	,	_	_	,	_	34	punct	_	_
# 33	cost-effective	_	_	JJ	_	34	amod	_	_
# 34	service	_	_	NN	_	30	pobj	_	_
# 35	.	_	_	.	_	11	punct	_	_
#
# 1	But	_	_	CC	_	4	expl	_	_
# 2	several	_	_	JJ	_	4	amod	_	_
# 3	committee	_	_	NN	_	4	nn	_	_
# 4	members	_	_	NNS	_	0	root	_	_
# 5	disapproved	_	_	VBD	_	4	rcmod	_	_
# 6	,	_	_	,	_	4	punct	_	_
# 7	some	_	_	DT	_	8	nsubj	_	_
# 8	backing	_	_	VBG	_	4	vmod	_	_
# 9	Mr.	_	_	NNP	_	10	nn	_	_
# 10	Trump	_	_	NNP	_	12	nn	_	_
# 11	's	_	_	POS	_	10	possessive	_	_
# 12	claim	_	_	NN	_	8	dobj	_	_
# 13	that	_	_	IN	_	15	det	_	_
# 14	the	_	_	DT	_	15	det	_	_
# 15	threat	_	_	NN	_	12	dobj	_	_
# 16	of	_	_	IN	_	15	prep	_	_
# 17	regulation	_	_	NN	_	16	pobj	_	_
# 18	caused	_	_	VBD	_	17	vmod	_	_
# 19	the	_	_	DT	_	20	det	_	_
# 20	failure	_	_	NN	_	18	dobj	_	_
# 21	of	_	_	IN	_	20	prep	_	_
# 22	the	_	_	DT	_	24	det	_	_
# 23	UAL	_	_	NNP	_	24	nn	_	_
# 24	deal	_	_	NN	_	28	nn	_	_
# 25	and	_	_	CC	_	24	cc	_	_
# 26	the	_	_	DT	_	28	det	_	_
# 27	stock-market	_	_	NN	_	28	nn	_	_
# 28	plunge	_	_	NN	_	21	pobj	_	_
# 29	.	_	_	.	_	4	punct	_	_
#
# 1	One	_	_	CD	_	16	nsubjpass	_	_
# 2	of	_	_	IN	_	1	prep	_	_
# 3	the	_	_	DT	_	5	det	_	_
# 4	major	_	_	JJ	_	5	amod	_	_
# 5	concerns	_	_	NNS	_	2	pobj	_	_
# 6	expressed	_	_	VBN	_	5	vmod	_	_
# 7	by	_	_	IN	_	6	prep	_	_
# 8	the	_	_	DT	_	9	det	_	_
# 9	dissenters	_	_	NNS	_	7	pobj	_	_
# 10	was	_	_	VBD	_	16	auxpass	_	_
# 11	that	_	_	IN	_	16	nsubjpass	_	_
# 12	large	_	_	JJ	_	13	amod	_	_
# 13	airlines	_	_	NNS	_	16	nsubjpass	_	_
# 14	would	_	_	MD	_	16	aux	_	_
# 15	be	_	_	VB	_	16	auxpass	_	_
# 16	prohibited	_	_	VBN	_	0	root	_	_
# 17	from	_	_	IN	_	16	prep	_	_
# 18	divesting	_	_	VBG	_	16	nsubj	_	_
# 19	themselves	_	_	PRP	_	18	dobj	_	_
# 20	of	_	_	IN	_	19	prep	_	_
# 21	smaller	_	_	JJR	_	22	amod	_	_
# 22	entities	_	_	NNS	_	20	pobj	_	_
# 23	and	_	_	CC	_	18	cc	_	_
# 24	producing	_	_	VBG	_	18	conj	_	_
# 25	independent	_	_	JJ	_	27	amod	_	_
# 26	spin-off	_	_	JJ	_	27	amod	_	_
# 27	companies	_	_	NNS	_	24	dobj	_	_
# 28	.	_	_	.	_	16	punct	_	_
#
# 1	A	_	_	DT	_	2	det	_	_
# 2	group	_	_	NN	_	9	nsubj	_	_
# 3	of	_	_	IN	_	2	prep	_	_
# 4	institutional	_	_	JJ	_	5	amod	_	_
# 5	investors	_	_	NNS	_	3	pobj	_	_
# 6	in	_	_	IN	_	5	prep	_	_
# 7	Telerate	_	_	NNP	_	8	nn	_	_
# 8	Inc.	_	_	NNP	_	6	pobj	_	_
# 9	said	_	_	VBD	_	0	root	_	_
# 10	that	_	_	IN	_	18	mark	_	_
# 11	Dow	_	_	NNP	_	12	nn	_	_
# 12	Jones	_	_	NNP	_	14	nn	_	_
# 13	&	_	_	CC	_	12	cc	_	_
# 14	Co.	_	_	NNP	_	18	tmod	_	_
# 15	's	_	_	POS	_	14	possessive	_	_
# 16	$	_	_	$	_	18	amod	_	_
# 17	18-a-share	_	_	JJ	_	18	amod	_	_
# 18	offer	_	_	NN	_	9	ccomp	_	_
# 19	for	_	_	IN	_	18	prep	_	_
# 20	the	_	_	DT	_	25	det	_	_
# 21	electronic	_	_	JJ	_	25	amod	_	_
# 22	financial	_	_	JJ	_	25	amod	_	_
# 23	information	_	_	NN	_	25	nn	_	_
# 24	services	_	_	NNS	_	25	nn	_	_
# 25	company	_	_	NN	_	29	tmod	_	_
# 26	is	_	_	VBZ	_	29	cop	_	_
# 27	``	_	_	``	_	29	punct	_	_
# 28	grossly	_	_	RB	_	29	advmod	_	_
# 29	inadequate	_	_	JJ	_	19	pobj	_	_
# 30	.	_	_	.	_	9	punct	_	_
# 31	''	_	_	''	_	9	punct	_	_
#
# 1	In	_	_	IN	_	32	prep	_	_
# 2	a	_	_	DT	_	3	det	_	_
# 3	letter	_	_	NN	_	1	pobj	_	_
# 4	filed	_	_	VBN	_	3	vmod	_	_
# 5	with	_	_	IN	_	4	prep	_	_
# 6	the	_	_	DT	_	7	det	_	_
# 7	Securities	_	_	NNP	_	10	nn	_	_
# 8	and	_	_	CC	_	7	cc	_	_
# 9	Exchange	_	_	NNP	_	10	nn	_	_
# 10	Commission	_	_	NNP	_	13	poss	_	_
# 11	,	_	_	,	_	10	punct	_	_
# 12	the	_	_	DT	_	13	det	_	_
# 13	group	_	_	NN	_	5	pobj	_	_
# 14	,	_	_	,	_	13	punct	_	_
# 15	which	_	_	WDT	_	16	nsubj	_	_
# 16	holds	_	_	VBZ	_	13	vmod	_	_
# 17	about	_	_	RB	_	19	quantmod	_	_
# 18	4.5	_	_	CD	_	19	number	_	_
# 19	million	_	_	CD	_	21	num	_	_
# 20	Telerate	_	_	NNP	_	21	nn	_	_
# 21	shares	_	_	NNS	_	16	dobj	_	_
# 22	,	_	_	,	_	21	punct	_	_
# 23	or	_	_	CC	_	16	cc	_	_
# 24	about	_	_	RB	_	25	quantmod	_	_
# 25	4.7	_	_	CD	_	26	num	_	_
# 26	%	_	_	NN	_	16	dobj	_	_
# 27	of	_	_	IN	_	26	prep	_	_
# 28	the	_	_	DT	_	29	det	_	_
# 29	shares	_	_	NNS	_	27	pobj	_	_
# 30	outstanding	_	_	JJ	_	29	amod	_	_
# 31	,	_	_	,	_	32	punct	_	_
# 32	said	_	_	VBD	_	0	root	_	_
# 33	``	_	_	``	_	32	punct	_	_
# 34	...	_	_	:	_	32	punct	_	_
# 35	at	_	_	IN	_	32	prep	_	_
# 36	present	_	_	JJ	_	35	pcomp	_	_
# 37	none	_	_	NN	_	40	nsubj	_	_
# 38	of	_	_	IN	_	37	prep	_	_
# 39	us	_	_	PRP	_	38	pobj	_	_
# 40	believes	_	_	VBZ	_	36	conj	_	_
# 41	an	_	_	DT	_	42	det	_	_
# 42	offer	_	_	NN	_	40	ccomp	_	_
# 43	for	_	_	IN	_	42	prep	_	_
# 44	less	_	_	JJR	_	43	pobj	_	_
# 45	than	_	_	IN	_	44	prep	_	_
# 46	$	_	_	$	_	55	nsubj	_	_
# 47	25	_	_	CD	_	46	num	_	_
# 48	per	_	_	IN	_	46	prep	_	_
# 49	share	_	_	NN	_	48	pobj	_	_
# 50	would	_	_	MD	_	52	aux	_	_
# 51	be	_	_	VB	_	52	cop	_	_
# 52	fair	_	_	JJ	_	46	vmod	_	_
# 53	and	_	_	CC	_	52	cc	_	_
# 54	some	_	_	DT	_	46	conj	_	_
# 55	believe	_	_	VBP	_	45	pcomp	_	_
# 56	that	_	_	DT	_	55	conj	_	_
# 57	$	_	_	$	_	56	conj	_	_
# 58	25	_	_	CD	_	57	num	_	_
# 59	is	_	_	VBZ	_	61	cop	_	_
# 60	too	_	_	RB	_	61	advmod	_	_
# 61	low	_	_	JJ	_	57	advmod	_	_
# 62	.	_	_	.	_	32	punct	_	_
# 63	''	_	_	''	_	32	punct	_	_
#
# 1	The	_	_	DT	_	2	det	_	_
# 2	letter	_	_	NN	_	4	nsubjpass	_	_
# 3	was	_	_	VBD	_	4	auxpass	_	_
# 4	dated	_	_	VBN	_	0	root	_	_
# 5	Oct.	_	_	NNP	_	4	tmod	_	_
# 6	6	_	_	CD	_	5	num	_	_
# 7	.	_	_	.	_	4	punct	_	_
#
# 1	In	_	_	IN	_	13	prep	_	_
# 2	composite	_	_	JJ	_	3	amod	_	_
# 3	trading	_	_	NN	_	1	pobj	_	_
# 4	on	_	_	IN	_	3	prep	_	_
# 5	the	_	_	DT	_	9	det	_	_
# 6	New	_	_	NNP	_	9	nn	_	_
# 7	York	_	_	NNP	_	9	nn	_	_
# 8	Stock	_	_	NNP	_	9	nn	_	_
# 9	Exchange	_	_	NNP	_	4	pobj	_	_
# 10	,	_	_	,	_	13	punct	_	_
# 11	Telerate	_	_	NNP	_	12	nn	_	_
# 12	shares	_	_	NNS	_	13	nsubj	_	_
# 13	closed	_	_	VBD	_	0	root	_	_
# 14	yesterday	_	_	NN	_	13	tmod	_	_
# 15	at	_	_	IN	_	13	prep	_	_
# 16	$	_	_	$	_	15	pobj	_	_
# 17	18.875	_	_	CD	_	16	num	_	_
# 18	,	_	_	,	_	13	punct	_	_
# 19	down	_	_	RB	_	13	advmod	_	_
# 20	75	_	_	CD	_	21	num	_	_
# 21	cents	_	_	NNS	_	19	pobj	_	_
# 22	a	_	_	DT	_	23	det	_	_
# 23	share	_	_	NN	_	21	npadvmod	_	_
# 24	.	_	_	.	_	13	punct	_	_
#
# 1	Dow	_	_	NNP	_	2	nn	_	_
# 2	Jones	_	_	NNP	_	12	nsubj	_	_
# 3	,	_	_	,	_	2	punct	_	_
# 4	publisher	_	_	NN	_	2	appos	_	_
# 5	of	_	_	IN	_	4	prep	_	_
# 6	The	_	_	DT	_	9	det	_	_
# 7	Wall	_	_	NNP	_	9	nn	_	_
# 8	Street	_	_	NNP	_	9	nn	_	_
# 9	Journal	_	_	NNP	_	5	pobj	_	_
# 10	,	_	_	,	_	2	punct	_	_
# 11	has	_	_	VBZ	_	12	aux	_	_
# 12	launched	_	_	VBN	_	0	root	_	_
# 13	an	_	_	DT	_	23	det	_	_
# 14	$	_	_	$	_	23	amod	_	_
# 15	18-a-share	_	_	JJ	_	23	amod	_	_
# 16	,	_	_	,	_	15	punct	_	_
# 17	or	_	_	CC	_	15	cc	_	_
# 18	$	_	_	$	_	23	amod	_	_
# 19	576	_	_	CD	_	20	number	_	_
# 20	million	_	_	CD	_	18	num	_	_
# 21	,	_	_	,	_	18	punct	_	_
# 22	tender	_	_	NN	_	23	nn	_	_
# 23	offer	_	_	NN	_	12	dobj	_	_
# 24	to	_	_	TO	_	25	aux	_	_
# 25	acquire	_	_	VB	_	23	conj	_	_
# 26	the	_	_	DT	_	29	det	_	_
# 27	remaining	_	_	JJ	_	29	amod	_	_
# 28	Telerate	_	_	NNP	_	29	nn	_	_
# 29	shares	_	_	NNS	_	25	dobj	_	_
# 30	outstanding	_	_	JJ	_	29	amod	_	_
# 31	;	_	_	:	_	12	punct	_	_
# 32	Dow	_	_	NNP	_	33	nn	_	_
# 33	Jones	_	_	NNP	_	12	tmod	_	_
# 34	owns	_	_	VBZ	_	33	rcmod	_	_
# 35	67	_	_	CD	_	36	num	_	_
# 36	%	_	_	NN	_	34	dobj	_	_
# 37	of	_	_	IN	_	36	prep	_	_
# 38	Telerate	_	_	NNP	_	37	pobj	_	_
# 39	.	_	_	.	_	12	punct	_	_
#
# 1	Telerate	_	_	NNP	_	3	nsubj	_	_
# 2	has	_	_	VBZ	_	3	aux	_	_
# 3	rejected	_	_	VBN	_	0	root	_	_
# 4	the	_	_	DT	_	5	det	_	_
# 5	offer	_	_	NN	_	3	dobj	_	_
# 6	,	_	_	,	_	5	punct	_	_
# 7	which	_	_	WDT	_	8	nsubj	_	_
# 8	expires	_	_	VBZ	_	5	rcmod	_	_
# 9	Nov.	_	_	NNP	_	8	tmod	_	_
# 10	3	_	_	CD	_	9	num	_	_
# 11	.	_	_	.	_	3	punct	_	_
#
# 1	The	_	_	DT	_	2	det	_	_
# 2	group	_	_	NN	_	3	nsubj	_	_
# 3	includes	_	_	VBZ	_	0	root	_	_
# 4	Putnam	_	_	NNP	_	3	dobj	_	_
# 5	Cos.	_	_	NNP	_	8	nn	_	_
# 6	and	_	_	CC	_	5	cc	_	_
# 7	various	_	_	JJ	_	8	amod	_	_
# 8	affiliates	_	_	NNS	_	9	nsubjpass	_	_
# 9	based	_	_	VBN	_	4	rcmod	_	_
# 10	in	_	_	IN	_	9	prep	_	_
# 11	Boston	_	_	NNP	_	15	nn	_	_
# 12	;	_	_	:	_	11	punct	_	_
# 13	Wells	_	_	NNP	_	15	nn	_	_
# 14	Fargo	_	_	NNP	_	15	nn	_	_
# 15	Bank	_	_	NNP	_	18	nn	_	_
# 16	,	_	_	,	_	15	punct	_	_
# 17	San	_	_	NNP	_	18	nn	_	_
# 18	Francisco	_	_	NNP	_	25	nn	_	_
# 19	;	_	_	:	_	18	punct	_	_
# 20	the	_	_	DT	_	25	det	_	_
# 21	California	_	_	NNP	_	25	nn	_	_
# 22	Public	_	_	NNP	_	25	nn	_	_
# 23	Employees	_	_	NNP	_	25	nn	_	_
# 24	Retirement	_	_	NNP	_	25	nn	_	_
# 25	System	_	_	NNP	_	27	nn	_	_
# 26	,	_	_	,	_	25	punct	_	_
# 27	Sacramento	_	_	NNP	_	36	nn	_	_
# 28	,	_	_	,	_	27	punct	_	_
# 29	Calif.	_	_	NNP	_	27	appos	_	_
# 30	,	_	_	,	_	27	punct	_	_
# 31	and	_	_	CC	_	27	cc	_	_
# 32	T.	_	_	NNP	_	36	nn	_	_
# 33	Rowe	_	_	NNP	_	36	nn	_	_
# 34	Price	_	_	NNP	_	36	nn	_	_
# 35	Associates	_	_	NNP	_	36	nn	_	_
# 36	Inc.	_	_	NNP	_	10	pobj	_	_
# 37	,	_	_	,	_	36	punct	_	_
# 38	Baltimore	_	_	NNP	_	36	conj	_	_
# 39	.	_	_	.	_	3	punct	_	_
#
# 1	Among	_	_	IN	_	9	prep	_	_
# 2	other	_	_	JJ	_	3	amod	_	_
# 3	issues	_	_	NNS	_	1	pobj	_	_
# 4	,	_	_	,	_	9	punct	_	_
# 5	the	_	_	DT	_	6	det	_	_
# 6	group	_	_	NN	_	8	nn	_	_
# 7	's	_	_	POS	_	6	possessive	_	_
# 8	letter	_	_	NN	_	9	nsubj	_	_
# 9	said	_	_	VBD	_	0	root	_	_
# 10	it	_	_	PRP	_	13	nsubj	_	_
# 11	has	_	_	VBZ	_	13	aux	_	_
# 12	``	_	_	``	_	13	punct	_	_
# 13	concerns	_	_	VBZ	_	9	ccomp	_	_
# 14	as	_	_	IN	_	13	prep	_	_
# 15	to	_	_	TO	_	13	prep	_	_
# 16	whether	_	_	IN	_	20	mark	_	_
# 17	Dow	_	_	NNP	_	18	nn	_	_
# 18	Jones	_	_	NNP	_	20	nn	_	_
# 19	's	_	_	POS	_	18	possessive	_	_
# 20	offer	_	_	NN	_	13	dobj	_	_
# 21	meets	_	_	VBZ	_	20	rcmod	_	_
# 22	the	_	_	DT	_	24	det	_	_
# 23	applicable	_	_	JJ	_	24	amod	_	_
# 24	requirements	_	_	NNS	_	21	dobj	_	_
# 25	of	_	_	IN	_	24	prep	_	_
# 26	procedural	_	_	JJ	_	27	amod	_	_
# 27	fairness	_	_	NN	_	25	pobj	_	_
# 28	.	_	_	.	_	9	punct	_	_
# 29	''	_	_	''	_	9	punct	_	_
#
# 1	A	_	_	DT	_	2	det	_	_
# 2	spokesman	_	_	NN	_	6	nsubj	_	_
# 3	for	_	_	IN	_	2	prep	_	_
# 4	Dow	_	_	NNP	_	5	nn	_	_
# 5	Jones	_	_	NNP	_	3	pobj	_	_
# 6	said	_	_	VBD	_	0	root	_	_
# 7	he	_	_	PRP	_	10	nsubj	_	_
# 8	had	_	_	VBD	_	10	aux	_	_
# 9	n't	_	_	RB	_	10	neg	_	_
# 10	seen	_	_	VBN	_	6	ccomp	_	_
# 11	the	_	_	DT	_	12	det	_	_
# 12	group	_	_	NN	_	10	dobj	_	_
# 13	's	_	_	POS	_	12	possessive	_	_
# 14	filing	_	_	NN	_	12	conj	_	_
# 15	,	_	_	,	_	6	punct	_	_
# 16	but	_	_	CC	_	6	cc	_	_
# 17	added	_	_	VBD	_	6	ccomp	_	_
# 18	,	_	_	,	_	17	punct	_	_
# 19	``	_	_	``	_	17	punct	_	_
# 20	obviously	_	_	RB	_	23	advmod	_	_
# 21	Dow	_	_	NNP	_	22	nn	_	_
# 22	Jones	_	_	NNP	_	23	nsubj	_	_
# 23	disagrees	_	_	VBZ	_	17	ccomp	_	_
# 24	with	_	_	IN	_	23	prep	_	_
# 25	their	_	_	PRP$	_	26	poss	_	_
# 26	conclusions	_	_	NNS	_	24	pobj	_	_
# 27	.	_	_	.	_	6	punct	_	_
#
# 1	Our	_	_	PRP$	_	2	poss	_	_
# 2	offer	_	_	NN	_	3	nsubj	_	_
# 3	is	_	_	VBZ	_	0	root	_	_
# 4	to	_	_	TO	_	5	aux	_	_
# 5	buy	_	_	VB	_	3	xcomp	_	_
# 6	any	_	_	DT	_	9	det	_	_
# 7	and	_	_	CC	_	6	cc	_	_
# 8	all	_	_	DT	_	9	det	_	_
# 9	shares	_	_	NNS	_	5	dobj	_	_
# 10	tendered	_	_	VBN	_	9	rcmod	_	_
# 11	at	_	_	IN	_	10	prep	_	_
# 12	$	_	_	$	_	11	pobj	_	_
# 13	18	_	_	CD	_	12	num	_	_
# 14	a	_	_	DT	_	15	det	_	_
# 15	share	_	_	NN	_	12	conj	_	_
# 16	.	_	_	.	_	3	punct	_	_

# %%
# !python3 evaluate.py data/model.h5 data/dev.conll
# Out:
# 2022-11-10 16:35:03.660163: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Evaluating. (Each . represents 100 test dependency trees)
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2067: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# ..................................................
# 5039 sentence.
#
# Micro Avg. Labeled Attachment Score: 0.6967405454259015
# Micro Avg. Unlabeled Attachment Score: 0.751042677213668
#
# Macro Avg. Labeled Attachment Score: 0.7032980389882125
# Macro Avg. Unlabeled Attachment Score: 0.7575730160070069
